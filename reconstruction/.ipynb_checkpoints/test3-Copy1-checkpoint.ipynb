# %%
from qiskit import QuantumCircuit, Aer, execute, transpile
from qiskit.providers.aer import AerSimulator
from qiskit.quantum_info import Statevector
from qiskit.providers.aer.noise import NoiseModel

from qiskit.providers.fake_provider import FakeWashington
from qiskit import QuantumCircuit, Aer, execute, transpile
from qiskit.providers.aer import AerSimulator
from qiskit.quantum_info import Statevector
from qiskit.providers.aer.noise import NoiseModel
from qiskit.transpiler import passes
from qiskit.transpiler.passmanager import PassManager
import pathlib
from pathlib import Path
import numpy as np
import pandas as pd
from math import pi
import random

import copy

import pickle
from qiskit.quantum_info import partial_trace, Statevector
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister

import argparse
from collections import defaultdict

import re


def remove_unmeasured_qubit_and_merge(counts):
    new_counts = defaultdict(int)  # 使用defaultdict方便累加重复结果
    for key, value in counts.items():
        new_key = key.split(' ')[-1]  # 去掉不被测量的qubits
        new_counts[new_key] += value  # 合并相同的结果
    return dict(new_counts)


def calculate_tvd(counts1, counts2, shots):
    """ 计算两个测量分布的总变异距离 (TVD) """
    # 归一化为概率分布
    prob1 = {k: v / shots for k, v in counts1.items()}
    prob2 = {k: v / shots for k, v in counts2.items()}
    
    # 合并两个分布中的所有键
    all_keys = set([key.split(' ')[-1] for key in list(prob1.keys())]).union(set([key.split(' ')[-1] for key in list(prob2.keys())]))
    
    # 计算总变异距离
    tvd = 0.5 * sum(abs(prob1.get(k, 0) - prob2.get(k, 0)) for k in all_keys)
    return tvd


simulator = Aer.get_backend('statevector_simulator')
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
quantum_gates = {
    'single_qubit': {
        'parameterized': {
            'u': {'params': ['theta', 'phi', 'lambda'], 'ranges': [[0, 2*np.pi], [0, 2*np.pi], [0, 2*np.pi]]},
            'p': {'params': ['lambda'], 'ranges': [[0, 2*np.pi]]},
            'rx': {'params': ['theta'], 'ranges': [[0, 2*np.pi]]},
            'ry': {'params': ['theta'], 'ranges': [[0, 2*np.pi]]},
            'rz': {'params': ['theta'], 'ranges': [[0, 2*np.pi]]}
        },
        'non_parameterized': [
            'x',
            'y',
            'z',
            'h',
            's',
            'sdg',
            't',
            'tdg',
            'sx',
            'sxdg'
        ]
    },
    'two_qubit': {
        'parameterized': {
            'crx': {'params': ['theta'], 'ranges': [[0, 2*np.pi]]},
            'cry': {'params': ['theta'], 'ranges': [[0, 2*np.pi]]},
            'crz': {'params': ['theta'], 'ranges': [[0, 2*np.pi]]},
            'cp': {'params': ['lambda'], 'ranges': [[0, 2*np.pi]]},
            'cu': {'params': ['theta', 'phi', 'lambda'], 'ranges': [[0, 2*np.pi], [0, 2*np.pi], [0, 2*np.pi]]},
            'rxx': {'params': ['theta'], 'ranges': [[0, 2*np.pi]]},
            'rzz': {'params': ['theta'], 'ranges': [[0, 2*np.pi]]}
        },
        'non_parameterized': [
            'cz',
            'cy',
            'ch',
            'csx',
            'ecr'
        ]
    }
}

# %%
quantum_gates = {
    'single_qubit': {
        'parameterized': {
            'rx': {'params': ['theta'], 'ranges': [[0, 2*np.pi]]},
            'ry': {'params': ['theta'], 'ranges': [[0, 2*np.pi]]},
            'rz': {'params': ['theta'], 'ranges': [[0, 2*np.pi]]}
        },
        'non_parameterized': [
            'x',
            'y', 
            'z',
            'h'
        ]
    },
    'two_qubit': {
        'parameterized': {
            'crz': {'params': ['theta'], 'ranges': [[0, 2*np.pi]]},
            'rzz': {'params': ['theta'], 'ranges': [[0, 2*np.pi]]}
        },
        'non_parameterized': [
            'cx',
            'cz'
        ]
    }
}

# %%
quantum_gates = {
    "single_qubit": {
        "parameterized": {
            "rx": {
                "params": ["theta"],
                "ranges": [[0, 2*np.pi]],  # 这里假设您已经导入了numpy或定义了pi
                "probability_change": "high",
                "recommended_params": [np.pi, np.pi/2]
            },
            "ry": {
                "params": ["theta"],
                "ranges": [[0, 2*np.pi]],  # 同上
                "probability_change": "high",
                "recommended_params": [np.pi, np.pi/2]
            }
        },
        "non_parameterized": {
            "x": {
                "probability_change": "high"
            },
            "y": {
                "probability_change": "high"
            },
            "h": {
                "probability_change": "high"
            }
        }
    },
    "two_qubit": {
        "parameterized": {
            "crx": {
                "params": ["theta"],
                "ranges": [[0, 2*np.pi]],  # 同上
                "probability_change": "high",
                "recommended_params": [np.pi]
            },
            "cry": {
                "params": ["theta"],
                "ranges": [[0, 2*np.pi]],  # 同上
                "probability_change": "high",
                "recommended_params": [np.pi]
            },
            "crz": {
                "params": ["theta"],
                "ranges": [[0, 2*np.pi]],  # 同上
                "probability_change": "high",
                "recommended_params": [np.pi]
            }
        },
        "non_parameterized": {
            "cx": {
                "probability_change": "high"
            },
            "cz": {
                "probability_change": "high"
            },
            # "swap": {
            #     "probability_change": "high"
            # },
            # "iswap": {
            #     "probability_change": "high",
            #     "phase_change": "high"
            # }
        }
    }
}

# %%
def calculate_num_of_extra_qubits(gate_list, qubit_index, eq_container, num_container, node_index):
    if node_index not in eq_container:
        eq_container[node_index] = {}
    for gate in gate_list:
        ind = num_container[0]
        if not gate:
            continue
        # print(gate)
        # print('********************')
        for qubit in gate[3]:
            if qubit.index != qubit_index:
                if qubit.index not in eq_container[node_index]:
                    eq_container[node_index][qubit.index] = ind
                    num_container[0] += 1
        if len(gate) == 5 and gate[4]:
            for cg in gate[4]:
                # print(cg)
                # print('++++++++++++++++++++')
                for qubit in cg[3]:
                    if qubit.index != qubit_index:
                        if qubit.index not in eq_container[node_index]:
                            eq_container[node_index][qubit.index] = ind
                            num_container[0] += 1
                if len(cg) == 5 and cg[4]:
                    calculate_num_of_extra_qubits(cg[4], qubit_index, eq_container, num_container, node_index)

# %%
def require_extra_qubit(gate_list):
    for gate in gate_list:
        if len(gate) == 5 and gate[4]:
            return True

    return False

def fliter_res(file, num=1000):
    operation_list = []
    eq_container = {}
    num_container = [0]
    result = 0
    for i, gate_list in enumerate(res[file]):
        if not require_extra_qubit(gate_list[-1]) or len(gate_list[-1]) in range(0, num):
            operation_list.append(gate_list)
            
            calculate_num_of_extra_qubits(gate_list[-1], gate_list[2].index, eq_container, num_container, i)
    
    # print(num_container[0])
    return num_container[0]

# %%
def generate_new_operation_list(gate_list, node_index, gate_list_container):
    if node_index not in gate_list_container:
        gate_list_container[node_index] = []  # 为每个节点创建独立的映射
    for gate in gate_list:
        if gate[:4] in gate_list_container[node_index]:
            if len(gate) == 4:
                continue
        else:
            gate_list_container[node_index].append(gate[:4])
        
        if len(gate) == 5 and gate[4]:
            generate_new_operation_list(gate[4], node_index, gate_list_container)
        
    return gate_list_container

# %%
def generate_gate(gate_list, new_qc, qubit_index, q_to_eq, ind_container, node_index, gate_list_container):
    new_operation_list = generate_new_operation_list(gate_list, node_index, gate_list_container)[node_index]
    new_operation_list.sort()
    # print(new_operation_list)
    # print('\n')

    # return new_operation_list
    eq = new_qc.qregs[-1]  # 获取辅助量子比特寄存器
    if node_index not in q_to_eq:
        q_to_eq[node_index] = {}  # 为每个节点创建独立的映射
    # if node_index not in gate_list_container:
    #     gate_list_container[node_index] = []  # 为每个节点创建独立的映射
    i = 1
    for gate in new_operation_list:
    # for gate in gate_list:
    #     if gate[:4] in gate_list_container[node_index]:
    #         continue
    #     gate_list_container[node_index].append(gate[:4])
                    
        ind = ind_container[0]
        # 确定目标量子比特的映射
        for qubit in gate[3]:
            if qubit.index != qubit_index:
                if qubit.index not in q_to_eq[node_index]:
                    q_to_eq[node_index][qubit.index] = ind
                    ind_container[0] += 1   # 更新 ind
        # print("Current q_to_eq mapping for node", node_index, ":", q_to_eq[node_index])  # 调试输出
        # 插入单比特门
        if len(gate) == 4 or (len(gate) == 5 and not gate[4]):
            # print('gate = ', gate)
            if len(gate[3]) == 2:
                # print('gate[3] = ', gate[3])
                # 确保控制和目标比特都使用当前节点内的辅助量子比特
                control_qubit = eq[q_to_eq[node_index][gate[3][0].index]] if gate[3][0].index in q_to_eq[node_index] else new_qc.qubits[qubit_index]
                target_qubit = eq[q_to_eq[node_index][gate[3][1].index]] if gate[3][1].index in q_to_eq[node_index] else new_qc.qubits[qubit_index]
                
                if not gate[2]:  # 无参数双比特门
                    getattr(new_qc, gate[1])(control_qubit, target_qubit)
                else:  # 有参数双比特门
                    if gate[1] == 'cu1':
                        gate[1] = 'cp'
                    para = gate[2][0]
                    # print('***************************')
                    # print(gate[1], para, control_qubit, target_qubit)
                    # print('***************************')
                    getattr(new_qc, gate[1])(para, control_qubit, target_qubit)
            else:
                target_qubit = eq[q_to_eq[node_index][gate[3][0].index]] if gate[3][0].index in q_to_eq[node_index] else new_qc.qubits[qubit_index]
                if not gate[2]:
                    getattr(new_qc, gate[1])(target_qubit)
                else:
                    if gate[1] in ['u2', 'u3']:
                        theta = pi/2 if gate[1] == 'u2' else gate[2][0]
                        phi = gate[2][0] if gate[1] == 'u2' else gate[2][1]
                        lam = gate[2][1] if gate[1] == 'u2' else gate[2][2]
                        getattr(new_qc, 'u')(theta, phi, lam, target_qubit)
                    elif gate[1] == 'u1':
                        getattr(new_qc, 'u')(0, 0, gate[2][0], target_qubit)
                    else:
                        para = gate[2][0]
                        # print(gate[1], para, target_qubit)
                        getattr(new_qc, gate[1])(para, target_qubit)
        
        # 插入双比特门
        else:
            # 如果存在嵌套操作，递归处理，并更新 `ind_container` 防止重用
            # if len(gate) == 5 and gate[4]:
            #     generate_gate(gate[4], new_qc, qubit_index, q_to_eq, ind_container, node_index, gate_list_container)
            # print('+++++++++++++++++++++++')
            # print(gate)
            # print('+++++++++++++++++++++++')
            # if gate[0] in ['cp', 'cx']:
            if len(gate[3]) == 2:
                # print('gate[3] = ', gate[3])
                # 确保控制和目标比特都使用当前节点内的辅助量子比特
                control_qubit = eq[q_to_eq[node_index][gate[3][0].index]] if gate[3][0].index in q_to_eq[node_index] else new_qc.qubits[qubit_index]
                target_qubit = eq[q_to_eq[node_index][gate[3][1].index]] if gate[3][1].index in q_to_eq[node_index] else new_qc.qubits[qubit_index]
                
                if not gate[2]:  # 无参数双比特门
                    getattr(new_qc, gate[1])(control_qubit, target_qubit)
                else:  # 有参数双比特门
                    if gate[1] == 'cu1':
                        gate[1] = 'cp'
                    para = gate[2][0]
                    # print('***************************')
                    # print(gate[1], para, control_qubit, target_qubit)
                    # print('***************************')
                    getattr(new_qc, gate[1])(para, control_qubit, target_qubit)
            else:
                target_qubit = eq[q_to_eq[node_index][gate[3][0].index]] if gate[3][0].index in q_to_eq[node_index] else new_qc.qubits[qubit_index]
                if not gate[1]:
                    getattr(new_qc, gate[1])(target_qubit)
                else:
                    if gate[1] in ['u2', 'u3']:
                        theta = pi/2 if gate[1] == 'u2' else gate[2][0]
                        phi = gate[2][0] if gate[1] == 'u2' else gate[2][1]
                        lam = gate[2][1] if gate[1] == 'u2' else gate[2][2]
                        getattr(new_qc, 'u')(theta, phi, lam, target_qubit)
                    elif gate[1] == 'u1':
                        getattr(new_qc, 'u')(0, 0, gate[2][0], target_qubit)
                    else:
                        para = gate[2][0]
                        # print(gate[0], para, target_qubit)
                        getattr(new_qc, gate[1])(para, target_qubit)
        
        if i == len(new_operation_list):
            new_qc.data[-1][0].label = "test_" + str(node_index)
            # print("reset")
        
        i += 1

# %%
def generate_monitoring_circuit(transpiled_qc, file, res, num=1000):
    # file = '../quantum circuits/' + file
    operation_list = []
    eq_container = {}
    num_container = [0]
    result = 0
    for i, gate_list in enumerate(res[file]):
        if not require_extra_qubit(gate_list[-1]) or len(gate_list[-1]) in range(0, num):
            # print(gate_list)
            # print(';;;;;;;;;;;;;;;;;;;;;;')
            # print('\n')
            operation_list.append(gate_list)
            # if i[1] in ['cp', 'cx']:
            #     num_container[0] += 1
            
            calculate_num_of_extra_qubits(gate_list[-1], gate_list[2].index, eq_container, num_container, i)

    # print(file, num_container[0], '\n')
    
    # qc = QuantumCircuit.from_qasm_file(file)
    # transpiled_qc = transpile(qc, simulator)
    # return transpiled_qc.data
    
    new_qc = QuantumCircuit()
    for reg in transpiled_qc.qregs:
        new_qc.add_register(QuantumRegister(reg.size, reg.name))
    for reg in transpiled_qc.cregs:
        new_qc.add_register(ClassicalRegister(reg.size, reg.name))
    # if new_qc.num_clbits < new_qc.num_qubits:
    #     new_qc.add_register(ClassicalRegister(new_qc.num_qubits - new_qc.num_clbits, 'ec'))
    ec = ClassicalRegister(len(operation_list), 'ec')
    new_qc.add_register(ec)
    
    # 增加额外的辅助量子比特寄存器
    if num_container[0] != 0:
        additional_qubits = QuantumRegister(num_container[0], 'eq')
        new_qc.add_register(additional_qubits)
    
    # 遍历并插入所有门
    ind_container = [0]
    ec_container = [0]
    q_to_eq = {}
    gate_list_container = {}
    level = 0
    for i, (instr, qargs, cargs) in enumerate(transpiled_qc.data):
        new_qc.append(instr, qargs, cargs)  # 添加原始的门操作
        
        for op in operation_list:
            if i == op[0]:
                # print('^^^^^^^^^^^^^^^^^^^^^^^^^^^^^')
                # print(op, '\n')
                # print('VVVVVVVVVVVVVVVVVVVVVVVVVVVVV')
                for qubit in qargs:
                    if transpiled_qc.find_bit(qubit) == op[2]:
                        # 插入测量、复位和恢复门操作
                        new_qc.measure(new_qc.qubits[op[2].index], ec[ec_container[0]])
                        ec_container[0] += 1
                        new_qc.reset(new_qc.qubits[op[2].index])
                        eq = new_qc.qregs[-1]
                        # print(op[-1], '\n')
                        generate_gate(op[-1], new_qc, op[2].index, q_to_eq, ind_container, i, gate_list_container)
    return new_qc

# %%
def find_probablity_new(qc, simulator):
    res = []
    partial_circuit = QuantumCircuit()
    for reg in qc.qregs:
        new_reg = QuantumRegister(reg.size, reg.name)
        partial_circuit.add_register(new_reg)
    for reg in qc.cregs:
        new_reg = ClassicalRegister(reg.size, reg.name)
        partial_circuit.add_register(new_reg)
    # print(qc.num_qubits)
    # qc = transpile(qc, simulator)
    for i, gate in enumerate(qc.data):
        # 创建一个新的电路，将所有先前的门加入到新的电路中
        # partial_circuit = QuantumCircuit(qc.num_qubits)
        partial_circuit.data = qc.data[:i+1]  # 只包含到第 i 步的操作
        
    
        # 模拟部分电路并获取态向量
        job = simulator.run(partial_circuit)
        result = job.result()
        statevector = result.get_statevector()
        
        # 将态向量转换为量子态对象
        quantum_state = Statevector(statevector)
        # quantum_state = Statevector.from_instruction(partial_circuit)
    
        # 提取与该门操作相关的量子比特的状态
        qubits_involved = [partial_circuit.find_bit(qubit) for qubit in gate[1]]  # 获取与该门相关的量子比特
        for qubit in qubits_involved:
            # if gate[0].name == 'u3':
            #     print('sjhfjg;kg;r')
            # 使用 partial_trace 仅提取该量子比特的状态
            qubit_state = partial_trace(quantum_state, [q for q in range(qc.num_qubits) if q != qubit.index])
            prob_zero = qubit_state.data[0, 0].real
            prob_one = qubit_state.data[1, 1].real
            res.append([i, gate[0].name, qubit, prob_zero, prob_one, gate[0].params, gate[0].label])
    return res

# %%
unwanted_circuit_list = []
with open('../limited_quantum_circuits_old/statevector_list.pkl', 'rb') as f:
    while True:
        try:
            item = pickle.load(f)
            # list = []
            qc = QuantumCircuit.from_qasm_file(item[0])
            for i, gate in enumerate(transpile(qc, simulator).data):
                if gate[0].name == 'ccx':
                    unwanted_circuit_list.append(str(item[0]))
                    break
        except EOFError:
            break

# %%
with open('../limited_quantum_circuits_old/opeartion_list_99.pkl', 'rb') as pickle_file:
    res = pickle.load(pickle_file)

len(res)
# Out:
# 96

# %%
res['../limited_quantum_circuits_old/portfoliovqe_indep_qiskit_8.qasm']
# Out:
# [[28,
#   'ry',
#   BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)]),
#   0.9998227680878257,
#   0.0001772319121745584,
#   [[28,
#     'ry',
#     [6.256558825358066],
#     [BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])]]]],
#  [29,
#   'cz',
#   BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)]),
#   0.9998227680878257,
#   0.0001772319121745584,
#   [[28,
#     'ry',
#     [6.256558825358066],
#     [BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])]],
#    [29,
#     'cz',
#     [],
#     [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     [[0,
#       'ry',
#       [-2.157666746655994],
#       [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)])]]]]]],
#  [31,
#   'cz',
#   BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)]),
#   0.9998227680878257,
#   0.0001772319121745584,
#   [[28,
#     'ry',
#     [6.256558825358066],
#     [BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])]],
#    [29,
#     'cz',
#     [],
#     [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [31,
#     'cz',
#     [],
#     [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     [[1,
#       'ry',
#       [-4.211782825246222],
#       [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)])]],
#      [2,
#       'cz',
#       [],
#       [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#        BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)])],
#       [[0,
#         'ry',
#         [-2.157666746655994],
#         [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)])]]]]]]]],
#  [34,
#   'cz',
#   BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)]),
#   0.9998227680878261,
#   0.0001772319121745584,
#   [[28,
#     'ry',
#     [6.256558825358066],
#     [BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])]],
#    [29,
#     'cz',
#     [],
#     [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [31,
#     'cz',
#     [],
#     [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [34,
#     'cz',
#     [],
#     [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     [[3,
#       'ry',
#       [-1.2370557945339522],
#       [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)])]],
#      [4,
#       'cz',
#       [],
#       [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#        BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)])],
#       []],
#      [5,
#       'cz',
#       [],
#       [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#        BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)])],
#       [[1,
#         'ry',
#         [-4.211782825246222],
#         [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)])]],
#        [2,
#         'cz',
#         [],
#         [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#          BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)])],
#         [[0,
#           'ry',
#           [-2.157666746655994],
#           [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)])]]]]]]]]]],
#  [38,
#   'cz',
#   BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)]),
#   0.9998227680878258,
#   0.00017723191217455838,
#   [[28,
#     'ry',
#     [6.256558825358066],
#     [BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])]],
#    [29,
#     'cz',
#     [],
#     [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [31,
#     'cz',
#     [],
#     [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [34,
#     'cz',
#     [],
#     [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [38,
#     'cz',
#     [],
#     [BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     [[6,
#       'ry',
#       [-1.835420271130908],
#       [BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)])]],
#      [7,
#       'cz',
#       [],
#       [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#        BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)])],
#       []],
#      [8,
#       'cz',
#       [],
#       [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#        BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)])],
#       []],
#      [9,
#       'cz',
#       [],
#       [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)]),
#        BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)])],
#       [[3,
#         'ry',
#         [-1.2370557945339522],
#         [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)])]],
#        [4,
#         'cz',
#         [],
#         [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#          BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)])],
#         []],
#        [5,
#         'cz',
#         [],
#         [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#          BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)])],
#         [[1,
#           'ry',
#           [-4.211782825246222],
#           [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)])]],
#          [2,
#           'cz',
#           [],
#           [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#            BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)])],
#           [[0,
#             'ry',
#             [-2.157666746655994],
#             [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)])]]]]]]]]]]]],
#  [43,
#   'cz',
#   BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)]),
#   0.9998227680878253,
#   0.00017723191217455843,
#   [[28,
#     'ry',
#     [6.256558825358066],
#     [BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])]],
#    [29,
#     'cz',
#     [],
#     [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [31,
#     'cz',
#     [],
#     [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [34,
#     'cz',
#     [],
#     [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [38,
#     'cz',
#     [],
#     [BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [43,
#     'cz',
#     [],
#     [BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     [[10,
#       'ry',
#       [5.675448631303404],
#       [BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)])]],
#      [11,
#       'cz',
#       [],
#       [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#        BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)])],
#       []],
#      [12,
#       'cz',
#       [],
#       [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#        BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)])],
#       []],
#      [13,
#       'cz',
#       [],
#       [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)]),
#        BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)])],
#       []],
#      [14,
#       'cz',
#       [],
#       [BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)]),
#        BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)])],
#       [[6,
#         'ry',
#         [-1.835420271130908],
#         [BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)])]],
#        [7,
#         'cz',
#         [],
#         [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#          BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)])],
#         []],
#        [8,
#         'cz',
#         [],
#         [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#          BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)])],
#         []],
#        [9,
#         'cz',
#         [],
#         [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)]),
#          BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)])],
#         [[3,
#           'ry',
#           [-1.2370557945339522],
#           [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)])]],
#          [4,
#           'cz',
#           [],
#           [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#            BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)])],
#           []],
#          [5,
#           'cz',
#           [],
#           [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#            BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)])],
#           [[1,
#             'ry',
#             [-4.211782825246222],
#             [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)])]],
#            [2,
#             'cz',
#             [],
#             [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#              BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)])],
#             [[0,
#               'ry',
#               [-2.157666746655994],
#               [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)])]]]]]]]]]]]]]],
#  [49,
#   'cz',
#   BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)]),
#   0.9998227680878259,
#   0.0001772319121745585,
#   [[28,
#     'ry',
#     [6.256558825358066],
#     [BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])]],
#    [29,
#     'cz',
#     [],
#     [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [31,
#     'cz',
#     [],
#     [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [34,
#     'cz',
#     [],
#     [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [38,
#     'cz',
#     [],
#     [BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [43,
#     'cz',
#     [],
#     [BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [49,
#     'cz',
#     [],
#     [BitLocations(index=5, registers=[(QuantumRegister(8, 'q'), 5)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     [[15,
#       'ry',
#       [1.992543527349273],
#       [BitLocations(index=5, registers=[(QuantumRegister(8, 'q'), 5)])]],
#      [16,
#       'cz',
#       [],
#       [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#        BitLocations(index=5, registers=[(QuantumRegister(8, 'q'), 5)])],
#       []],
#      [17,
#       'cz',
#       [],
#       [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#        BitLocations(index=5, registers=[(QuantumRegister(8, 'q'), 5)])],
#       []],
#      [18,
#       'cz',
#       [],
#       [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)]),
#        BitLocations(index=5, registers=[(QuantumRegister(8, 'q'), 5)])],
#       []],
#      [19,
#       'cz',
#       [],
#       [BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)]),
#        BitLocations(index=5, registers=[(QuantumRegister(8, 'q'), 5)])],
#       []],
#      [20,
#       'cz',
#       [],
#       [BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)]),
#        BitLocations(index=5, registers=[(QuantumRegister(8, 'q'), 5)])],
#       [[10,
#         'ry',
#         [5.675448631303404],
#         [BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)])]],
#        [11,
#         'cz',
#         [],
#         [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#          BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)])],
#         []],
#        [12,
#         'cz',
#         [],
#         [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#          BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)])],
#         []],
#        [13,
#         'cz',
#         [],
#         [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)]),
#          BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)])],
#         []],
#        [14,
#         'cz',
#         [],
#         [BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)]),
#          BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)])],
#         [[6,
#           'ry',
#           [-1.835420271130908],
#           [BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)])]],
#          [7,
#           'cz',
#           [],
#           [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#            BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)])],
#           []],
#          [8,
#           'cz',
#           [],
#           [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#            BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)])],
#           []],
#          [9,
#           'cz',
#           [],
#           [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)]),
#            BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)])],
#           [[3,
#             'ry',
#             [-1.2370557945339522],
#             [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)])]],
#            [4,
#             'cz',
#             [],
#             [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#              BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)])],
#             []],
#            [5,
#             'cz',
#             [],
#             [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#              BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)])],
#             [[1,
#               'ry',
#               [-4.211782825246222],
#               [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)])]],
#              [2,
#               'cz',
#               [],
#               [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#                BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)])],
#               [[0,
#                 'ry',
#                 [-2.157666746655994],
#                 [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)])]]]]]]]]]]]]]]]],
#  [56,
#   'cz',
#   BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)]),
#   0.9998227680878257,
#   0.0001772319121745584,
#   [[28,
#     'ry',
#     [6.256558825358066],
#     [BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])]],
#    [29,
#     'cz',
#     [],
#     [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [31,
#     'cz',
#     [],
#     [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [34,
#     'cz',
#     [],
#     [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [38,
#     'cz',
#     [],
#     [BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [43,
#     'cz',
#     [],
#     [BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [49,
#     'cz',
#     [],
#     [BitLocations(index=5, registers=[(QuantumRegister(8, 'q'), 5)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     []],
#    [56,
#     'cz',
#     [],
#     [BitLocations(index=6, registers=[(QuantumRegister(8, 'q'), 6)]),
#      BitLocations(index=7, registers=[(QuantumRegister(8, 'q'), 7)])],
#     [[21,
#       'ry',
#       [-3.9614120325075177],
#       [BitLocations(index=6, registers=[(QuantumRegister(8, 'q'), 6)])]],
#      [22,
#       'cz',
#       [],
#       [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#        BitLocations(index=6, registers=[(QuantumRegister(8, 'q'), 6)])],
#       []],
#      [23,
#       'cz',
#       [],
#       [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#        BitLocations(index=6, registers=[(QuantumRegister(8, 'q'), 6)])],
#       []],
#      [24,
#       'cz',
#       [],
#       [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)]),
#        BitLocations(index=6, registers=[(QuantumRegister(8, 'q'), 6)])],
#       []],
#      [25,
#       'cz',
#       [],
#       [BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)]),
#        BitLocations(index=6, registers=[(QuantumRegister(8, 'q'), 6)])],
#       []],
#      [26,
#       'cz',
#       [],
#       [BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)]),
#        BitLocations(index=6, registers=[(QuantumRegister(8, 'q'), 6)])],
#       []],
#      [27,
#       'cz',
#       [],
#       [BitLocations(index=5, registers=[(QuantumRegister(8, 'q'), 5)]),
#        BitLocations(index=6, registers=[(QuantumRegister(8, 'q'), 6)])],
#       [[15,
#         'ry',
#         [1.992543527349273],
#         [BitLocations(index=5, registers=[(QuantumRegister(8, 'q'), 5)])]],
#        [16,
#         'cz',
#         [],
#         [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#          BitLocations(index=5, registers=[(QuantumRegister(8, 'q'), 5)])],
#         []],
#        [17,
#         'cz',
#         [],
#         [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#          BitLocations(index=5, registers=[(QuantumRegister(8, 'q'), 5)])],
#         []],
#        [18,
#         'cz',
#         [],
#         [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)]),
#          BitLocations(index=5, registers=[(QuantumRegister(8, 'q'), 5)])],
#         []],
#        [19,
#         'cz',
#         [],
#         [BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)]),
#          BitLocations(index=5, registers=[(QuantumRegister(8, 'q'), 5)])],
#         []],
#        [20,
#         'cz',
#         [],
#         [BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)]),
#          BitLocations(index=5, registers=[(QuantumRegister(8, 'q'), 5)])],
#         [[10,
#           'ry',
#           [5.675448631303404],
#           [BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)])]],
#          [11,
#           'cz',
#           [],
#           [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#            BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)])],
#           []],
#          [12,
#           'cz',
#           [],
#           [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#            BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)])],
#           []],
#          [13,
#           'cz',
#           [],
#           [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)]),
#            BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)])],
#           []],
#          [14,
#           'cz',
#           [],
#           [BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)]),
#            BitLocations(index=4, registers=[(QuantumRegister(8, 'q'), 4)])],
#           [[6,
#             'ry',
#             [-1.835420271130908],
#             [BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)])]],
#            [7,
#             'cz',
#             [],
#             [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#              BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)])],
#             []],
#            [8,
#             'cz',
#             [],
#             [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#              BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)])],
#             []],
#            [9,
#             'cz',
#             [],
#             [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)]),
#              BitLocations(index=3, registers=[(QuantumRegister(8, 'q'), 3)])],
#             [[3,
#               'ry',
#               [-1.2370557945339522],
#               [BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)])]],
#              [4,
#               'cz',
#               [],
#               [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#                BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)])],
#               []],
#              [5,
#               'cz',
#               [],
#               [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)]),
#                BitLocations(index=2, registers=[(QuantumRegister(8, 'q'), 2)])],
#               [[1,
#                 'ry',
#                 [-4.211782825246222],
#                 [BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)])]],
#                [2,
#                 'cz',
#                 [],
#                 [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)]),
#                  BitLocations(index=1, registers=[(QuantumRegister(8, 'q'), 1)])],
#                 [[0,
#                   'ry',
#                   [-2.157666746655994],
#                   [BitLocations(index=0, registers=[(QuantumRegister(8, 'q'), 0)])]]]]]]]]]]]]]]]]]]]

# %%
res_new = {}
for key, value in res.items():
    # if key == '../limited quantum circuits/qpeexact_indep_qiskit_8.qasm':
    #     print(key, fliter_res(key))
    if fliter_res(key, 1000) <= 10 and key not in [str(i) for i in unwanted_circuit_list]:
    # if key not in unwanted_circuit_list:
    # if fliter_res(key) <= 20:
        res_new[key] = value

# %%
for k in res_new:
    print(k)
# Out:
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_8.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_10.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_6.qasm
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_10.qasm
# ../limited_quantum_circuits_old/grover-v-chain_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_7.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_9.qasm
# ../limited_quantum_circuits_old/portfoliovqe_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/routing_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_10.qasm
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_9.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_6.qasm
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_7.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_6.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/tsp_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_7.qasm
# ../limited_quantum_circuits_old/portfoliovqe_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_8.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_9.qasm
# ../limited_quantum_circuits_old/random_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/qft_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_8.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_7.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_10.qasm
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_6.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_9.qasm
# ../limited_quantum_circuits_old/routing_indep_qiskit_6.qasm
# ../limited_quantum_circuits_old/qft_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/random_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_8.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_8.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_6.qasm
# ../limited_quantum_circuits_old/grover-noancilla_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/qft_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_10.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_7.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_9.qasm

# %%
len(res_new)
# Out:
# 60

# %%
for k, v in res_new.items():
    qc = QuantumCircuit.from_qasm_file(k)
    transpiled_qc = transpile(qc, simulator)
    for l in v:
        if l[1] != transpiled_qc.data[l[0]][0].name:
            print(k)
            break

# %%
del res_new['../limited_quantum_circuits/random_indep_qiskit_6.qasm']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 del res_new['../limited_quantum_circuits/random_indep_qiskit_6.qasm']
#
# KeyError: '../limited_quantum_circuits/random_indep_qiskit_6.qasm'

# %%
comparison_circuit = {}
for key in res_new:
    try:
        qc = QuantumCircuit.from_qasm_file(key)
        transpiled_qc = transpile(qc, simulator)
        comparison_circuit[key] = generate_monitoring_circuit(transpiled_qc, key, res, 1000)
    except Exception as e:
        print(e)

# %%
# shots = 8192
# execution_result = []
# for key in res_new:
#     qc = QuantumCircuit.from_qasm_file(key)
#     try:
#         new_qc = comparison_circuit[key]
#         result_qc = execute(qc, backend=Aer.get_backend('qasm_simulator'), shots=shots).result().get_counts()
#         result_qc = remove_unmeasured_qubit_and_merge(result_qc)
    
#         result_new_qc = execute(new_qc, backend=Aer.get_backend('qasm_simulator'), shots=shots).result().get_counts()
#         result_new_qc = remove_unmeasured_qubit_and_merge(result_new_qc)
        
#         execution_result.append([{key:[result_qc, result_new_qc, calculate_tvd(result_qc, result_new_qc, shots)]}])
#     except Exception as e:
#         print(e)

# %%
def remove_first_qubit_and_merge(counts):
    new_counts = defaultdict(int)  # 使用defaultdict方便累加重复结果
    for key, value in counts.items():
        new_key = key[1:]  # 去掉第一个量子比特
        new_counts[new_key] += value  # 合并相同的结果
    return dict(new_counts)

# %%
unblanced_circuit_list = []
for key in res_new:
    qc = QuantumCircuit.from_qasm_file(key)
    result_qc = execute(qc, backend=Aer.get_backend('qasm_simulator'), shots=8192).result()
    if len(list(result_qc.get_counts().keys())[0]) < qc.num_qubits:
        print(key)
        unblanced_circuit_list.append(key)
    # print(qc.num_qubits)
# Out:
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_6.qasm
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_7.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_8.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_9.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_10.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_3.qasm

# %%
def get_possible_outputs(file, unblanced_circuit_list):
    """
    通过量子态向量 (statevector) 获取所有可能的输出状态。

    参数:
    qc (QuantumCircuit): 量子电路对象
    
    返回:
    possible_states (list): 包含所有可能输出基态的列表
    """
    qc = QuantumCircuit.from_qasm_file(file)
    qc.remove_final_measurements()

    reconstructed_qc = comparison_circuit[file]
    reconstructed_qc.remove_final_measurements()
    
    # 在 statevector_simulator 上运行电路
    backend = Aer.get_backend('statevector_simulator')
    
    result = execute(qc, backend=backend).result()
    result_reconstructed_qc = execute(reconstructed_qc, backend=backend).result()
    
    # 获取量子态向量
    statevector = result.get_statevector()
    statevector_reconstructed_qc = result_reconstructed_qc.get_statevector()
    # return statevector_reconstructed_qc
    
    # 判断不为零的态（概率幅不为零的部分）
    num_qubits = qc.num_qubits  # 量子比特数
    num_qubits_reconstructed_qc = reconstructed_qc.num_qubits  # 量子比特数
    
    possible_states = []
    possible_states_reconstructed_qc = []
    
    for idx, amplitude in enumerate(statevector):
        # 判断概率幅的模值是否接近 0
        if not np.isclose(np.abs(amplitude), 0, atol=1e-5):
            # 将索引转换为二进制字符串（填充到量子比特数的长度）
            binary_state = format(idx, f'0{num_qubits}b') if file not in unblanced_circuit_list else format(idx, f'0{num_qubits}b')[1:]
            possible_states.append(binary_state)
    
    len_binary_state = len(possible_states[0])
    # print(len_binary_state)
    

    for idx, amplitude in enumerate(statevector_reconstructed_qc):
        # 判断概率幅的模值是否接近 0
        if not np.isclose(np.abs(amplitude), 0, atol=1e-5):
            # 将索引转换为二进制字符串（填充到量子比特数的长度）
            binary_state = format(idx, f'0{num_qubits_reconstructed_qc}b')[-len_binary_state:]
            possible_states_reconstructed_qc.append(binary_state)
    
    return list(set(possible_states)), list(set(possible_states_reconstructed_qc))

# %%
for key, value in comparison_circuit.items():
    possible_result_list, possible_reconstructed_list = get_possible_outputs(key, unblanced_circuit_list)
    if not set(possible_reconstructed_list).issubset(set(possible_result_list)):
        print(key)
# Out:
# /var/folders/07/mn1lw68s3d903fldy_g4tqmm0000gn/T/ipykernel_15143/3157769564.py:35: DeprecationWarning: The return type of saved statevectors has been changed from a `numpy.ndarray` to a `qiskit.quantum_info.Statevector` as of qiskit-aer 0.10. Accessing numpy array attributes is deprecated and will result in an error in a future release. To continue using saved result objects as arrays you can explicitly cast them using  `np.asarray(object)`.
#   for idx, amplitude in enumerate(statevector):
# /var/folders/07/mn1lw68s3d903fldy_g4tqmm0000gn/T/ipykernel_15143/3157769564.py:46: DeprecationWarning: The return type of saved statevectors has been changed from a `numpy.ndarray` to a `qiskit.quantum_info.Statevector` as of qiskit-aer 0.10. Accessing numpy array attributes is deprecated and will result in an error in a future release. To continue using saved result objects as arrays you can explicitly cast them using  `np.asarray(object)`.
#   for idx, amplitude in enumerate(statevector_reconstructed_qc):
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_6.qasm
# ../limited_quantum_circuits_old/grover-v-chain_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_7.qasm
# ../limited_quantum_circuits_old/routing_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_10.qasm
# ../limited_quantum_circuits_old/grover-noancilla_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_9.qasm

# %%
uneven_result_list = []

with open('../data/execution_result_99_old.pkl', 'rb') as file:
    execution_result = pickle.load(file)
for er in execution_result:
    # actual_result_list = [k.split(' ')[-1] for k in list(list(er[0].items())[0][1][1].keys())]
    key = list(er[0].items())[0][0]
    if key not in res_new:
        continue
    possible_result_list, possible_reconstructed_list = get_possible_outputs(key, unblanced_circuit_list)
    if not set(possible_reconstructed_list).issubset(set(possible_result_list)) or list(er[0].items())[0][1][2] >= 0.1:
    # if list(er[0].items())[0][1][2] >= 0.5:
        print(key)
        uneven_result_list.append(key)
# Out:
# /var/folders/07/mn1lw68s3d903fldy_g4tqmm0000gn/T/ipykernel_15143/3157769564.py:35: DeprecationWarning: The return type of saved statevectors has been changed from a `numpy.ndarray` to a `qiskit.quantum_info.Statevector` as of qiskit-aer 0.10. Accessing numpy array attributes is deprecated and will result in an error in a future release. To continue using saved result objects as arrays you can explicitly cast them using  `np.asarray(object)`.
#   for idx, amplitude in enumerate(statevector):
# /var/folders/07/mn1lw68s3d903fldy_g4tqmm0000gn/T/ipykernel_15143/3157769564.py:46: DeprecationWarning: The return type of saved statevectors has been changed from a `numpy.ndarray` to a `qiskit.quantum_info.Statevector` as of qiskit-aer 0.10. Accessing numpy array attributes is deprecated and will result in an error in a future release. To continue using saved result objects as arrays you can explicitly cast them using  `np.asarray(object)`.
#   for idx, amplitude in enumerate(statevector_reconstructed_qc):
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_10.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_6.qasm
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_10.qasm
# ../limited_quantum_circuits_old/grover-v-chain_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_7.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_9.qasm
# ../limited_quantum_circuits_old/routing_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_10.qasm
# ../limited_quantum_circuits_old/tsp_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_9.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_10.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_9.qasm
# ../limited_quantum_circuits_old/grover-noancilla_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_10.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_9.qasm

# %%
uneven_result_list
# Out:
# ['../limited_quantum_circuits_old/qpeexact_indep_qiskit_5.qasm',
#  '../limited_quantum_circuits_old/realamprandom_indep_qiskit_10.qasm',
#  '../limited_quantum_circuits_old/vqe_indep_qiskit_6.qasm',
#  '../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_10.qasm',
#  '../limited_quantum_circuits_old/grover-v-chain_indep_qiskit_3.qasm',
#  '../limited_quantum_circuits_old/vqe_indep_qiskit_7.qasm',
#  '../limited_quantum_circuits_old/su2random_indep_qiskit_9.qasm',
#  '../limited_quantum_circuits_old/routing_indep_qiskit_2.qasm',
#  '../limited_quantum_circuits_old/vqe_indep_qiskit_10.qasm',
#  '../limited_quantum_circuits_old/tsp_indep_qiskit_4.qasm',
#  '../limited_quantum_circuits_old/realamprandom_indep_qiskit_9.qasm',
#  '../limited_quantum_circuits_old/su2random_indep_qiskit_10.qasm',
#  '../limited_quantum_circuits_old/qpeinexact_indep_qiskit_9.qasm',
#  '../limited_quantum_circuits_old/grover-noancilla_indep_qiskit_3.qasm',
#  '../limited_quantum_circuits_old/qpeinexact_indep_qiskit_10.qasm',
#  '../limited_quantum_circuits_old/vqe_indep_qiskit_5.qasm',
#  '../limited_quantum_circuits_old/vqe_indep_qiskit_9.qasm']

# %%
result = {}
simulator = Aer.get_backend('statevector_simulator')
pm = PassManager(passes.RemoveFinalMeasurements())
for key, value in comparison_circuit.items():
    print(key)
    new_qc_no_meas = pm.run(value)
    result[key] =  find_probablity_new(new_qc_no_meas, simulator)
# Out:
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_8.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_10.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_6.qasm
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_10.qasm
# ../limited_quantum_circuits_old/grover-v-chain_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_7.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_9.qasm
# ../limited_quantum_circuits_old/portfoliovqe_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/routing_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_10.qasm
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_9.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_6.qasm
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_7.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_6.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/tsp_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_7.qasm
# ../limited_quantum_circuits_old/portfoliovqe_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_8.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_9.qasm
# ../limited_quantum_circuits_old/random_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/qft_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_8.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_7.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_10.qasm
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_6.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_9.qasm
# ../limited_quantum_circuits_old/routing_indep_qiskit_6.qasm
# ../limited_quantum_circuits_old/qft_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/random_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_8.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_8.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_6.qasm
# ../limited_quantum_circuits_old/grover-noancilla_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/qft_indep_qiskit_4.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_10.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_5.qasm
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_3.qasm
# ../limited_quantum_circuits_old/su2random_indep_qiskit_7.qasm
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_2.qasm
# ../limited_quantum_circuits_old/vqe_indep_qiskit_9.qasm

# %%
unexpected_result_list = []

count = 0
for key, value in result.items():
    print(key)
    flag = True
    for i in value:
        if (i[-1] and i[-1].split('_')[0] == 'test') and i[2][1][0][0].name != 'eq':
            # print(i)
            # if i[3] < 0.99 and i[4] < 0.99:
            #     print(i[3], r[3], i[4], r[4])
            #     flag = False
            #     continue
            index = int(i[-1].split('_')[1])
            # print(index)
            for r in res_new[key]:
                # print(r)
                if r[0] == index:
                    if i[2].index != r[2].index:
                        continue
                    if abs(i[3] - r[3]) >= 1e-2 or abs(i[4] - r[4])>= 1e-2:
                        print(i[2], r[2], i[3], r[3], i[4], r[4])
                        flag = False
                        continue
    print('***********************', '\n')
    if not flag:
        count += 1
        unexpected_result_list.append(key)


print(count)
# Out:
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_3.qasm
# ***********************
#
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_5.qasm
# BitLocations(index=1, registers=[(QuantumRegister(4, 'q'), 1)]) BitLocations(index=1, registers=[(QuantumRegister(4, 'q'), 1)]) 0.5 0.9999999999999999 0.5 2.048440760755309e-32
# BitLocations(index=1, registers=[(QuantumRegister(4, 'q'), 1)]) BitLocations(index=1, registers=[(QuantumRegister(4, 'q'), 1)]) 0.5000000000000001 0.9999999999999999 0.5 2.048440760755309e-32
# BitLocations(index=2, registers=[(QuantumRegister(4, 'q'), 2)]) BitLocations(index=2, registers=[(QuantumRegister(4, 'q'), 2)]) 0.8535533905932751 0.9999999999999998 0.1464466094067262 1.396154609023427e-32
# ***********************
#
# ../limited_quantum_circuits_old/su2random_indep_qiskit_4.qasm
# ***********************
#
# ../limited_quantum_circuits_old/su2random_indep_qiskit_8.qasm
# ***********************
#
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_10.qasm
# ***********************
#
# ../limited_quantum_circuits_old/vqe_indep_qiskit_6.qasm
# ***********************
#
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_10.qasm
# ***********************
#
# ../limited_quantum_circuits_old/grover-v-chain_indep_qiskit_3.qasm
# BitLocations(index=1, registers=[(QuantumRegister(2, 'q'), 1)]) BitLocations(index=1, registers=[(QuantumRegister(2, 'q'), 1)]) 0.49999999999999983 1.4200651372405631e-32 0.5 1.0
# ***********************
#
# ../limited_quantum_circuits_old/vqe_indep_qiskit_7.qasm
# ***********************
#
# ../limited_quantum_circuits_old/su2random_indep_qiskit_9.qasm
# ***********************
#
# ../limited_quantum_circuits_old/portfoliovqe_indep_qiskit_5.qasm
# ***********************
#
# ../limited_quantum_circuits_old/routing_indep_qiskit_2.qasm
# BitLocations(index=0, registers=[(QuantumRegister(2, 'q'), 0)]) BitLocations(index=0, registers=[(QuantumRegister(2, 'q'), 0)]) 0.9106886471913089 0.9904560912800344 0.08931135280869133 0.009543908719965888
# BitLocations(index=0, registers=[(QuantumRegister(2, 'q'), 0)]) BitLocations(index=0, registers=[(QuantumRegister(2, 'q'), 0)]) 0.9106886471913088 0.9904560912800345 0.08931135280869133 0.00954390871996589
# ***********************
#
# ../limited_quantum_circuits_old/su2random_indep_qiskit_5.qasm
# ***********************
#
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_2.qasm
# ***********************
#
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_4.qasm
# ***********************
#
# ../limited_quantum_circuits_old/vqe_indep_qiskit_10.qasm
# ***********************
#
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_9.qasm
# ***********************
#
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_6.qasm
# ***********************
#
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_5.qasm
# ***********************
#
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_3.qasm
# ***********************
#
# ../limited_quantum_circuits_old/su2random_indep_qiskit_2.qasm
# ***********************
#
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_7.qasm
# ***********************
#
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_6.qasm
# ***********************
#
# ../limited_quantum_circuits_old/su2random_indep_qiskit_3.qasm
# ***********************
#
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_4.qasm
# ***********************
#
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_2.qasm
# ***********************
#
# ../limited_quantum_circuits_old/tsp_indep_qiskit_4.qasm
# BitLocations(index=2, registers=[(QuantumRegister(4, 'q'), 2)]) BitLocations(index=2, registers=[(QuantumRegister(4, 'q'), 2)]) 0.9805342529532609 0.9930476308166305 0.01946574704673896 0.006952369183369495
# BitLocations(index=2, registers=[(QuantumRegister(4, 'q'), 2)]) BitLocations(index=2, registers=[(QuantumRegister(4, 'q'), 2)]) 0.9805342529532625 0.9930476308166305 0.019465747046739024 0.006952369183369495
# BitLocations(index=2, registers=[(QuantumRegister(4, 'q'), 2)]) BitLocations(index=2, registers=[(QuantumRegister(4, 'q'), 2)]) 0.9805342529532614 0.9930476308166305 0.019465747046738917 0.006952369183369493
# ***********************
#
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_7.qasm
# ***********************
#
# ../limited_quantum_circuits_old/portfoliovqe_indep_qiskit_3.qasm
# ***********************
#
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_8.qasm
# ***********************
#
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_4.qasm
# ***********************
#
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_9.qasm
# ***********************
#
# ../limited_quantum_circuits_old/random_indep_qiskit_2.qasm
# ***********************
#
# ../limited_quantum_circuits_old/qft_indep_qiskit_3.qasm
# ***********************
#
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_8.qasm
# ***********************
#
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_5.qasm
# ***********************
#
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_7.qasm
# ***********************
#
# ../limited_quantum_circuits_old/su2random_indep_qiskit_10.qasm
# ***********************
#
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_6.qasm
# ***********************
#
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_4.qasm
# ***********************
#
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_9.qasm
# BitLocations(index=6, registers=[(QuantumRegister(8, 'q'), 6)]) BitLocations(index=6, registers=[(QuantumRegister(8, 'q'), 6)]) 0.8076157952903132 0.006432540718423054 0.19238420470968653 0.9935674592815765
# ***********************
#
# ../limited_quantum_circuits_old/routing_indep_qiskit_6.qasm
# ***********************
#
# ../limited_quantum_circuits_old/qft_indep_qiskit_2.qasm
# ***********************
#
# ../limited_quantum_circuits_old/random_indep_qiskit_3.qasm
# ***********************
#
# ../limited_quantum_circuits_old/vqe_indep_qiskit_3.qasm
# ***********************
#
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_8.qasm
# ***********************
#
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_5.qasm
# ***********************
#
# ../limited_quantum_circuits_old/vqe_indep_qiskit_8.qasm
# ***********************
#
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_3.qasm
# ***********************
#
# ../limited_quantum_circuits_old/su2random_indep_qiskit_6.qasm
# ***********************
#
# ../limited_quantum_circuits_old/grover-noancilla_indep_qiskit_3.qasm
# BitLocations(index=1, registers=[(QuantumRegister(2, 'q'), 1)]) BitLocations(index=1, registers=[(QuantumRegister(2, 'q'), 1)]) 0.49999999999999983 1.4200651372405631e-32 0.5 1.0
# ***********************
#
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_2.qasm
# ***********************
#
# ../limited_quantum_circuits_old/vqe_indep_qiskit_4.qasm
# ***********************
#
# ../limited_quantum_circuits_old/qft_indep_qiskit_4.qasm
# ***********************
#
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_10.qasm
# BitLocations(index=6, registers=[(QuantumRegister(9, 'q'), 6)]) BitLocations(index=6, registers=[(QuantumRegister(9, 'q'), 6)]) 0.3904493799215651 0.994873329914371 0.6095506200784367 0.0051266700856292605
# BitLocations(index=6, registers=[(QuantumRegister(9, 'q'), 6)]) BitLocations(index=6, registers=[(QuantumRegister(9, 'q'), 6)]) 0.3904493799215654 0.994873329914371 0.6095506200784352 0.0051266700856292605
# BitLocations(index=7, registers=[(QuantumRegister(9, 'q'), 7)]) BitLocations(index=7, registers=[(QuantumRegister(9, 'q'), 7)]) 0.8124297440711922 0.9968457298906622 0.18757025592880666 0.003154270109337723
# ***********************
#
# ../limited_quantum_circuits_old/vqe_indep_qiskit_5.qasm
# ***********************
#
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_3.qasm
# ***********************
#
# ../limited_quantum_circuits_old/su2random_indep_qiskit_7.qasm
# ***********************
#
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_2.qasm
# ***********************
#
# ../limited_quantum_circuits_old/vqe_indep_qiskit_9.qasm
# ***********************
#
# 7

# %%
bad_list = list(set(uneven_result_list + unexpected_result_list))
bad_list
# Out:
# ['../limited_quantum_circuits_old/tsp_indep_qiskit_4.qasm',
#  '../limited_quantum_circuits_old/routing_indep_qiskit_2.qasm',
#  '../limited_quantum_circuits_old/qpeinexact_indep_qiskit_9.qasm',
#  '../limited_quantum_circuits_old/vqe_indep_qiskit_9.qasm',
#  '../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_10.qasm',
#  '../limited_quantum_circuits_old/vqe_indep_qiskit_6.qasm',
#  '../limited_quantum_circuits_old/grover-v-chain_indep_qiskit_3.qasm',
#  '../limited_quantum_circuits_old/vqe_indep_qiskit_7.qasm',
#  '../limited_quantum_circuits_old/realamprandom_indep_qiskit_10.qasm',
#  '../limited_quantum_circuits_old/qpeexact_indep_qiskit_5.qasm',
#  '../limited_quantum_circuits_old/su2random_indep_qiskit_9.qasm',
#  '../limited_quantum_circuits_old/realamprandom_indep_qiskit_9.qasm',
#  '../limited_quantum_circuits_old/su2random_indep_qiskit_10.qasm',
#  '../limited_quantum_circuits_old/grover-noancilla_indep_qiskit_3.qasm',
#  '../limited_quantum_circuits_old/qpeinexact_indep_qiskit_10.qasm',
#  '../limited_quantum_circuits_old/vqe_indep_qiskit_10.qasm',
#  '../limited_quantum_circuits_old/vqe_indep_qiskit_5.qasm']

# %%
def mutate_circuit(transpiled_qc, mutation_idx, quantum_gates) -> QuantumCircuit:
    """
    Mutate a quantum circuit by randomly selecting a gate from the index_list
    and replacing it with a compatible gate (single->single, two->two qubit).
    
    Args:
        circuit: Original quantum circuit
        index_list: List of indices indicating which gates can be mutated
        quantum_gates: Dictionary containing gate information
        
    Returns:
        QuantumCircuit: Mutated circuit
    """
    
    def get_random_params(param_info):
        """Generate random parameters for a gate based on its ranges"""
        return [random.uniform(range_[0], range_[1]) for range_ in param_info['ranges']]
    
    def get_random_gate(is_single_qubit: bool):
        """Get a random gate of specified type (single/two qubit)"""
        gate_type = 'single_qubit' if is_single_qubit else 'two_qubit'
        # Decide if we want parameterized or non-parameterized gate
        is_parameterized = random.choice([True, False])
        
        if is_parameterized:
            gate_name = random.choice(list(quantum_gates[gate_type]['parameterized'].keys()))
            params = get_random_params(quantum_gates[gate_type]['parameterized'][gate_name])
            return gate_name, params
        else:
            gate_name = random.choice(list(quantum_gates[gate_type]['non_parameterized'].keys()))
            return gate_name, None

    # Create a copy of the circuit
    new_qc = QuantumCircuit()
    for reg in transpiled_qc.qregs:
        new_qc.add_register(QuantumRegister(reg.size, reg.name))
    for reg in transpiled_qc.cregs:
        new_qc.add_register(ClassicalRegister(reg.size, reg.name))
    
    # Choose random index from index_list
    # mutation_idx = random.choice(index_list)
    
    # Get all gates and their locations from the original circuit
    gates_list = []
    current_idx = 0
    
    for current_idx, (instr, qargs, cargs) in enumerate(transpiled_qc.data):
        qubits = [qc.find_bit(qubit) for qubit in qargs]
        params = instr.params if hasattr(instr, 'params') else []
        
        if current_idx == mutation_idx:
            # Determine if it's a single or two qubit gate
            is_single = len(qubits) == 1
            
            # Get random replacement gate
            new_gate_name, new_params = get_random_gate(is_single)
            print(new_gate_name, new_params)
            
            # Add the new gate to the circuit
                        # For gates with parameters
            if new_params:
                getattr(new_qc, new_gate_name)(*new_params, *[new_qc.qubits[q.index] for q in qubits])
            else:
                getattr(new_qc, new_gate_name)(*[new_qc.qubits[q.index] for q in qubits])
        else:
            # Copy the original gate
            # if params:
            #     getattr(new_qc, instr.name)(*params, *[new_qc.qubits(q.index) for q in qubits])
            # else:
            #     getattr(new_qc, instr.name)(*[new_qc.qubits(q.index) for q in qubits])
            new_qc.append(instr, qargs, cargs)
    
    return new_qc

# %%
res_definite_output = {}

for key, value in res_new.items():
    qc = QuantumCircuit.from_qasm_file(key)
    result_qc = execute(qc, backend=Aer.get_backend('qasm_simulator'), shots=8192).result()
    if len(result_qc.get_counts()) == 1 and key not in bad_list:
        print(key, result_qc.get_counts())
        res_definite_output[key] = value
# Out:
# ../limited quantum circuits/qpeexact_indep_qiskit_4.qasm {'100': 8192}
# ../limited quantum circuits/qpeexact_indep_qiskit_3.qasm {'10': 8192}
# ../limited quantum circuits/qpeexact_indep_qiskit_2.qasm {'1': 8192}
# ../limited quantum circuits/vqe_indep_qiskit_4.qasm {'0110': 8192}

# %%
pattern = re.compile(r"_(\d+)\.qasm$")
count = 0
random.seed(1234)
pm = PassManager(passes.RemoveFinalMeasurements())
mutation_execution_result = {}
for key, value in res_new.items():
    # match = pattern.search(key)
    # if match:
    #     qubit_count = int(match.group(1))  # 提取 qubit 数量
    #     if qubit_count > 5:
    #         continue
    if key not in bad_list:
        print(key)
        index_list = []
        assertion_value_list = []
        for gate_list in value:
            if not require_extra_qubit(gate_list[-1]) or len(gate_list[-1]) in range(0, 1000):
                index_list.append(gate_list[0])
                assertion_value_list.append({0 if gate_list[3] >= 0.99 else 1: gate_list[3] if gate_list[3] >= 0.99 else gate_list[4]})
        
        mutation_execution_result[key] = [index_list, assertion_value_list, {}]
        # print(mutation_execution_result[key])

        qc = QuantumCircuit.from_qasm_file(key)
        transpiled_qc = transpile(qc, simulator)
        num_gate = len(pm.run(transpiled_qc).data)
        print(index_list, num_gate)
        if index_list[-1] < 3:
            continue
        count += 1
        # continue
        # print(num_gate)
        # continue

        mutation_idx_list = random.sample(index_list, 3)
        print(mutation_idx_list)
        continue
        
        for mutation_idx in mutation_idx_list:
            mutation_qc = mutate_circuit(transpiled_qc, mutation_idx, quantum_gates)
            reconstructed_mutation_qc = generate_monitoring_circuit(mutation_qc, key, res, num=1000)
            result_reconstructed_mutation_qc = execute(reconstructed_mutation_qc, backend=Aer.get_backend('qasm_simulator'), shots=8192).result().get_counts()

            new_counts = defaultdict(int)  # 使用defaultdict方便累加重复结果
            for k, v in result_reconstructed_mutation_qc.items():
                new_key = k.split(' ')[0][::-1]
                new_counts[new_key] += v  # 合并相同的结果
            # print(new_counts)
            mutation_execution_result[key][2][mutation_idx] = [dict(new_counts)]
            
            # 计算总数
            total = sum(new_counts.values())
            
            # 初始化计数字典
            bit_count = defaultdict(int)
            
            # 计算每一位的0和1的频数
            for bitstring, stringcount in new_counts.items():
                for i, bit in enumerate(bitstring):
                    bit_count[(i, bit)] += stringcount
            
            # 计算并输出每一位0和1的频数百分比
            bit_percentages = {}
            for (position, bit), count in bit_count.items():
                bit_percentages[(position, bit)] = (count / total)

            mutation_execution_result[key][2][mutation_idx].append(dict(bit_percentages))

            
            
count
# Out:
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_3.qasm
# [1] 21
# ../limited_quantum_circuits_old/su2random_indep_qiskit_4.qasm
# [1] 34
# ../limited_quantum_circuits_old/su2random_indep_qiskit_8.qasm
# [1, 10, 12] 116
# ../limited_quantum_circuits_old/portfoliovqe_indep_qiskit_5.qasm
# [1, 2, 5, 8, 13, 14, 15, 19, 23, 28] 50
# ../limited_quantum_circuits_old/su2random_indep_qiskit_5.qasm
# [1, 10, 13] 50
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_2.qasm
# [1] 11
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_4.qasm
# [3, 6, 7, 8] 12
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_9.qasm
# [1, 10, 12] 144
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_6.qasm
# [5, 6, 7, 8, 9] 28
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_5.qasm
# [1, 10, 13] 50
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_3.qasm
# [2, 5] 8
# ../limited_quantum_circuits_old/su2random_indep_qiskit_2.qasm
# [1] 11
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_7.qasm
# [1, 10, 12] 91
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_6.qasm
# [1, 10, 12] 69
# ../limited_quantum_circuits_old/su2random_indep_qiskit_3.qasm
# [1] 21
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_4.qasm
# [1, 16] 34
# ../limited_quantum_circuits_old/qpeexact_indep_qiskit_2.qasm
# [1] 4
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_7.qasm
# [6, 7, 8, 9, 10, 11] 37
# ../limited_quantum_circuits_old/portfoliovqe_indep_qiskit_3.qasm
# [3, 4, 6] 21
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_8.qasm
# [1, 10, 12] 116
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_4.qasm
# [3, 4, 5] 14
# ../limited_quantum_circuits_old/random_indep_qiskit_2.qasm
# [0, 1, 10, 11] 16
# ../limited_quantum_circuits_old/qft_indep_qiskit_3.qasm
# [1, 3, 4] 7
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_8.qasm
# [7, 8, 9, 10, 11, 12, 13] 46
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_5.qasm
# [1, 10, 13] 50
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_7.qasm
# [1, 10, 12] 91
# ../limited_quantum_circuits_old/twolocalrandom_indep_qiskit_6.qasm
# [1, 10, 12] 69
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_4.qasm
# [1, 16] 34
# ../limited_quantum_circuits_old/routing_indep_qiskit_6.qasm
# [12, 20, 20] 39
# ../limited_quantum_circuits_old/qft_indep_qiskit_2.qasm
# [1] 4
# ../limited_quantum_circuits_old/random_indep_qiskit_3.qasm
# [0, 2, 8, 10, 11, 13] 16
# ../limited_quantum_circuits_old/vqe_indep_qiskit_3.qasm
# [1, 2, 3, 3] 13
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_8.qasm
# [1, 10, 12] 116
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_5.qasm
# [4, 5, 6, 7] 21
# ../limited_quantum_circuits_old/vqe_indep_qiskit_8.qasm
# [1, 3, 5, 9, 11, 13, 25, 27] 38
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_3.qasm
# [1] 21
# ../limited_quantum_circuits_old/su2random_indep_qiskit_6.qasm
# [1, 10, 12, 20, 24, 28, 33, 39] 69
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_2.qasm
# [1] 4
# ../limited_quantum_circuits_old/vqe_indep_qiskit_4.qasm
# [1, 5, 13] 18
# ../limited_quantum_circuits_old/qft_indep_qiskit_4.qasm
# [1, 3, 4, 6, 7, 8] 12
# ../limited_quantum_circuits_old/qpeinexact_indep_qiskit_3.qasm
# [2, 3] 9
# ../limited_quantum_circuits_old/su2random_indep_qiskit_7.qasm
# [1, 10, 12] 91
# ../limited_quantum_circuits_old/realamprandom_indep_qiskit_2.qasm
# [1] 11
# 33

# %%
mutation_execution_result
# Out:
# {'../limited quantum circuits/twolocalrandom_indep_qiskit_3.qasm': [[1],
#   [{0: 0.9957557381974962}],
#   {}],
#  '../limited quantum circuits/su2random_indep_qiskit_4.qasm': [[1],
#   [{0: 0.9957557381974963}],
#   {}],
#  '../limited quantum circuits/su2random_indep_qiskit_8.qasm': [[1, 10, 12],
#   [{0: 0.9957557381974962}, {1: 0.9999780006920682}, {1: 0.9957339256312092}],
#   {}],
#  '../limited quantum circuits/su2random_indep_qiskit_5.qasm': [[1, 10, 13],
#   [{0: 0.9957557381974962}, {1: 0.9999780006920681}, {1: 0.9957339256312089}],
#   {}],
#  '../limited quantum circuits/twolocalrandom_indep_qiskit_2.qasm': [[1],
#   [{0: 0.9957557381974962}],
#   {}],
#  '../limited quantum circuits/qpeexact_indep_qiskit_4.qasm': [[3, 6, 7, 8],
#   [{1: 1.0},
#    {0: 0.9999999999999999},
#    {0: 0.9999999999999999},
#    {0: 0.9999999999999998}],
#   {}],
#  '../limited quantum circuits/twolocalrandom_indep_qiskit_9.qasm': [[1,
#    10,
#    12],
#   [{0: 0.9957557381974962}, {1: 0.9999780006920683}, {1: 0.9957339256312091}],
#   {}],
#  '../limited quantum circuits/qpeinexact_indep_qiskit_6.qasm': [[5,
#    6,
#    7,
#    8,
#    9],
#   [{1: 1.0},
#    {1: 1.0},
#    {1: 0.9999999999999999},
#    {1: 0.9999999999999999},
#    {1: 0.9999999999999999}],
#   {}],
#  '../limited quantum circuits/twolocalrandom_indep_qiskit_5.qasm': [[1,
#    10,
#    13],
#   [{0: 0.9957557381974962}, {1: 0.9999780006920684}, {1: 0.9957339256312091}],
#   {}],
#  '../limited quantum circuits/qpeexact_indep_qiskit_3.qasm': [[2, 5],
#   [{1: 1.0}, {0: 1.0}],
#   {}],
#  '../limited quantum circuits/su2random_indep_qiskit_2.qasm': [[1],
#   [{0: 0.9957557381974962}],
#   {}],
#  '../limited quantum circuits/realamprandom_indep_qiskit_7.qasm': [[1, 10, 12],
#   [{0: 0.9957557381974962}, {1: 0.9999780006920683}, {1: 0.9957339256312091}],
#   {}],
#  '../limited quantum circuits/realamprandom_indep_qiskit_6.qasm': [[1, 10, 12],
#   [{0: 0.9957557381974962}, {1: 0.9999780006920682}, {1: 0.9957339256312092}],
#   {}],
#  '../limited quantum circuits/su2random_indep_qiskit_3.qasm': [[1],
#   [{0: 0.9957557381974962}],
#   {}],
#  '../limited quantum circuits/twolocalrandom_indep_qiskit_4.qasm': [[1, 16],
#   [{0: 0.9957557381974962}, {1: 0.9987259307933419}],
#   {}],
#  '../limited quantum circuits/qpeexact_indep_qiskit_2.qasm': [[1],
#   [{1: 1.0}],
#   {}],
#  '../limited quantum circuits/qpeinexact_indep_qiskit_7.qasm': [[6,
#    7,
#    8,
#    9,
#    10,
#    11],
#   [{1: 1.0}, {1: 1.0}, {1: 1.0}, {1: 1.0}, {1: 1.0}, {1: 1.0}],
#   {}],
#  '../limited quantum circuits/portfoliovqe_indep_qiskit_3.qasm': [[3, 4, 6],
#   [{1: 0.999979108851477}, {1: 0.999979108851477}, {1: 0.9999791088514771}],
#   {}],
#  '../limited quantum circuits/twolocalrandom_indep_qiskit_8.qasm': [[1,
#    10,
#    12],
#   [{0: 0.9957557381974962}, {1: 0.9999780006920683}, {1: 0.9957339256312091}],
#   {}],
#  '../limited quantum circuits/qpeinexact_indep_qiskit_4.qasm': [[3, 4, 5],
#   [{1: 1.0}, {1: 1.0}, {1: 1.0}],
#   {}],
#  '../limited quantum circuits/realamprandom_indep_qiskit_9.qasm': [[1, 10, 12],
#   [{0: 0.9957557381974962}, {1: 0.9999780006920683}, {1: 0.9957339256312091}],
#   {}],
#  '../limited quantum circuits/random_indep_qiskit_2.qasm': [[0, 1, 10, 11],
#   [{0: 1.0}, {0: 1.0}, {0: 0.998382670078652}, {1: 0.9973782859232678}],
#   {}],
#  '../limited quantum circuits/qft_indep_qiskit_3.qasm': [[1, 3, 4],
#   [{0: 1.0}, {0: 1.0}, {0: 1.0}],
#   {}],
#  '../limited quantum circuits/qpeinexact_indep_qiskit_8.qasm': [[7,
#    8,
#    9,
#    10,
#    11,
#    12,
#    13],
#   [{1: 1.0}, {1: 1.0}, {1: 1.0}, {1: 1.0}, {1: 1.0}, {1: 1.0}, {1: 1.0}],
#   {}],
#  '../limited quantum circuits/realamprandom_indep_qiskit_5.qasm': [[1, 10, 13],
#   [{0: 0.9957557381974962}, {1: 0.9999780006920684}, {1: 0.9957339256312091}],
#   {}],
#  '../limited quantum circuits/twolocalrandom_indep_qiskit_7.qasm': [[1,
#    10,
#    12],
#   [{0: 0.9957557381974962}, {1: 0.9999780006920683}, {1: 0.9957339256312091}],
#   {}],
#  '../limited quantum circuits/twolocalrandom_indep_qiskit_6.qasm': [[1,
#    10,
#    12],
#   [{0: 0.9957557381974962}, {1: 0.9999780006920682}, {1: 0.9957339256312092}],
#   {}],
#  '../limited quantum circuits/realamprandom_indep_qiskit_4.qasm': [[1, 16],
#   [{0: 0.9957557381974962}, {1: 0.9987259307933419}],
#   {}],
#  '../limited quantum circuits/routing_indep_qiskit_6.qasm': [[12, 20, 20],
#   [{1: 0.993318528829914}, {1: 0.9933185288299139}, {1: 0.9947911454946503}],
#   {}],
#  '../limited quantum circuits/qft_indep_qiskit_2.qasm': [[1], [{0: 1.0}], {}],
#  '../limited quantum circuits/random_indep_qiskit_3.qasm': [[0,
#    2,
#    8,
#    10,
#    11,
#    13],
#   [{1: 0.9983826700786523},
#    {0: 0.9999999999999999},
#    {1: 0.9983826700786524},
#    {1: 0.9983826700786524},
#    {1: 0.9983826700786522},
#    {1: 0.9983826700786522}],
#   {}],
#  '../limited quantum circuits/vqe_indep_qiskit_3.qasm': [[1, 2, 3, 3],
#   [{0: 0.996010270185238},
#    {1: 1.0},
#    {0: 0.996010270185238},
#    {1: 0.996010270185238}],
#   {}],
#  '../limited quantum circuits/realamprandom_indep_qiskit_8.qasm': [[1, 10, 12],
#   [{0: 0.9957557381974962}, {1: 0.9999780006920683}, {1: 0.9957339256312091}],
#   {}],
#  '../limited quantum circuits/qpeinexact_indep_qiskit_5.qasm': [[4, 5, 6, 7],
#   [{1: 1.0}, {1: 1.0}, {1: 1.0}, {1: 1.0}],
#   {}],
#  '../limited quantum circuits/vqe_indep_qiskit_8.qasm': [[1,
#    3,
#    5,
#    9,
#    11,
#    13,
#    25,
#    27],
#   [{1: 1.0},
#    {0: 0.9999999994607807},
#    {1: 0.9999997772946067},
#    {1: 0.9999997772946067},
#    {0: 0.9999999994607809},
#    {1: 1.0000000000000004},
#    {0: 0.9999995382303907},
#    {1: 0.9999999907924549}],
#   {}],
#  '../limited quantum circuits/realamprandom_indep_qiskit_3.qasm': [[1],
#   [{0: 0.9957557381974962}],
#   {}],
#  '../limited quantum circuits/qpeinexact_indep_qiskit_2.qasm': [[1],
#   [{1: 1.0}],
#   {}],
#  '../limited quantum circuits/vqe_indep_qiskit_4.qasm': [[1, 5, 13],
#   [{0: 0.9999999853450323}, {0: 0.9999999853450322}, {0: 0.9995518203242044}],
#   {}],
#  '../limited quantum circuits/qpeinexact_indep_qiskit_3.qasm': [[2, 3],
#   [{1: 1.0}, {1: 1.0}],
#   {}],
#  '../limited quantum circuits/su2random_indep_qiskit_7.qasm': [[1, 10, 12],
#   [{0: 0.9957557381974962}, {1: 0.999978000692068}, {1: 0.995733925631209}],
#   {}],
#  '../limited quantum circuits/realamprandom_indep_qiskit_2.qasm': [[1],
#   [{0: 0.9957557381974962}],
#   {}]}

# %%
for key, value in mutation_execution_result.items():
    print(key)
    for i, dic in enumerate(mutation_execution_result[key][1]):
        # print((i, str(list(dic.keys())[0])), list(dic.values())[0])
        for k, v in mutation_execution_result[key][2].items():
            # print((i, str(list(dic.keys())[0])), v[1][(i, str(list(dic.keys())[0]))])
            if abs(list(dic.values())[0] - v[1][(i, str(list(dic.keys())[0]))]) >= 1e-2:
                print((i, str(list(dic.keys())[0])), list(dic.values())[0], (i, str(list(dic.keys())[0])), v[1][(i, str(list(dic.keys())[0]))])

    print('\n')
        # break
        # print(mutation_execution_result['../limited quantum circuits/su2random_indep_qiskit_8.qasm'][2][48][1][(i, str(list(dic.keys())[0]))])
# Out:
# ../limited quantum circuits/twolocalrandom_indep_qiskit_3.qasm
# (0, '0') 0.9957557381974962 (0, '0') 0.50830078125
#
#
# ../limited quantum circuits/su2random_indep_qiskit_4.qasm
#
#
# ../limited quantum circuits/su2random_indep_qiskit_8.qasm
# (2, '1') 0.9957339256312092 (2, '1') 0.17333984375
#
#
# ../limited quantum circuits/portfoliovqe_indep_qiskit_5.qasm
#
#
# ../limited quantum circuits/su2random_indep_qiskit_5.qasm
# (2, '1') 0.9957339256312089 (2, '1') 0.4954833984375
#
#
# ../limited quantum circuits/twolocalrandom_indep_qiskit_2.qasm
#
#
# ../limited quantum circuits/qpeexact_indep_qiskit_4.qasm
# (0, '1') 1.0 (0, '1') 0.5025634765625
# (1, '0') 0.9999999999999999 (1, '0') 0.4990234375
# (1, '0') 0.9999999999999999 (1, '0') 0.9444580078125
#
#
# ../limited quantum circuits/twolocalrandom_indep_qiskit_9.qasm
#
#
# ../limited quantum circuits/qpeinexact_indep_qiskit_6.qasm
#
#
# ../limited quantum circuits/twolocalrandom_indep_qiskit_5.qasm
#
#
# ../limited quantum circuits/qpeexact_indep_qiskit_3.qasm
# (0, '1') 1.0 (0, '1') 0.3663330078125
# (1, '0') 1.0 (1, '0') 0.2237548828125
#
#
# ../limited quantum circuits/su2random_indep_qiskit_2.qasm
#
#
# ../limited quantum circuits/realamprandom_indep_qiskit_7.qasm
#
#
# ../limited quantum circuits/realamprandom_indep_qiskit_6.qasm
# (1, '1') 0.9999780006920682 (1, '1') 0.507080078125
#
#
# ../limited quantum circuits/su2random_indep_qiskit_3.qasm
#
#
# ../limited quantum circuits/twolocalrandom_indep_qiskit_4.qasm
# (1, '1') 0.9987259307933419 (1, '1') 0.5174560546875
#
#
# ../limited quantum circuits/qpeexact_indep_qiskit_2.qasm

# %%
for key, value in mutation_execution_result['../limited_quantum_circuits/su2random_indep_qiskit_8.qasm'][2].items():
    print(value)
# Out:
# [{'011': 8113, '111': 33, '010': 46}, {(0, '0'): 0.9959716796875, (1, '1'): 1.0, (2, '1'): 0.994384765625, (0, '1'): 0.0040283203125, (2, '0'): 0.005615234375}]

# %%
for key in res_new:
    if key not in bad_list:
        print(key)
# Out:
# ../limited quantum circuits/twolocalrandom_indep_qiskit_3.qasm
# ../limited quantum circuits/su2random_indep_qiskit_4.qasm
# ../limited quantum circuits/su2random_indep_qiskit_8.qasm
# ../limited quantum circuits/portfoliovqe_indep_qiskit_5.qasm
# ../limited quantum circuits/su2random_indep_qiskit_5.qasm
# ../limited quantum circuits/twolocalrandom_indep_qiskit_2.qasm
# ../limited quantum circuits/qpeexact_indep_qiskit_4.qasm
# ../limited quantum circuits/twolocalrandom_indep_qiskit_9.qasm
# ../limited quantum circuits/qpeinexact_indep_qiskit_6.qasm
# ../limited quantum circuits/twolocalrandom_indep_qiskit_5.qasm
# ../limited quantum circuits/qpeexact_indep_qiskit_3.qasm
# ../limited quantum circuits/su2random_indep_qiskit_2.qasm
# ../limited quantum circuits/realamprandom_indep_qiskit_7.qasm
# ../limited quantum circuits/realamprandom_indep_qiskit_6.qasm
# ../limited quantum circuits/su2random_indep_qiskit_3.qasm
# ../limited quantum circuits/twolocalrandom_indep_qiskit_4.qasm
# ../limited quantum circuits/qpeexact_indep_qiskit_2.qasm
# ../limited quantum circuits/qpeinexact_indep_qiskit_7.qasm
# ../limited quantum circuits/portfoliovqe_indep_qiskit_3.qasm
# ../limited quantum circuits/twolocalrandom_indep_qiskit_8.qasm
# ../limited quantum circuits/qpeinexact_indep_qiskit_4.qasm
# ../limited quantum circuits/realamprandom_indep_qiskit_9.qasm
# ../limited quantum circuits/random_indep_qiskit_2.qasm
# ../limited quantum circuits/qft_indep_qiskit_3.qasm
# ../limited quantum circuits/qpeinexact_indep_qiskit_8.qasm
# ../limited quantum circuits/realamprandom_indep_qiskit_5.qasm
# ../limited quantum circuits/twolocalrandom_indep_qiskit_7.qasm
# ../limited quantum circuits/twolocalrandom_indep_qiskit_6.qasm
# ../limited quantum circuits/realamprandom_indep_qiskit_4.qasm
# ../limited quantum circuits/routing_indep_qiskit_6.qasm
# ../limited quantum circuits/qft_indep_qiskit_2.qasm
# ../limited quantum circuits/random_indep_qiskit_3.qasm
# ../limited quantum circuits/vqe_indep_qiskit_3.qasm
# ../limited quantum circuits/realamprandom_indep_qiskit_8.qasm
# ../limited quantum circuits/qpeinexact_indep_qiskit_5.qasm
# ../limited quantum circuits/vqe_indep_qiskit_8.qasm
# ../limited quantum circuits/realamprandom_indep_qiskit_3.qasm
# ../limited quantum circuits/su2random_indep_qiskit_6.qasm
# ../limited quantum circuits/qpeinexact_indep_qiskit_2.qasm
# ../limited quantum circuits/vqe_indep_qiskit_4.qasm
# ../limited quantum circuits/qft_indep_qiskit_4.qasm
# ../limited quantum circuits/qpeinexact_indep_qiskit_3.qasm
# ../limited quantum circuits/su2random_indep_qiskit_7.qasm
# ../limited quantum circuits/realamprandom_indep_qiskit_2.qasm

# %%
index_list = []
for gate_list in res_new['../limited_quantum_circuits/realamprandom_indep_qiskit_9.qasm']:
    if len(gate_list[-1]) in range(0, 1000):
        index_list.append(gate_list[0])
        print(0 if gate_list[3] >= 0.9 else 1, gate_list[3] if gate_list[3] >= 0.9 else gate_list[4])
index_list
# Out:
# 0 0.9957557381974962
# 1 0.9999780006920683
# 1 0.9957339256312091
# [1, 10, 12]

# %%
qc = QuantumCircuit.from_qasm_file('../limited_quantum_circuits/realamprandom_indep_qiskit_9.qasm')
# qc.draw('mpl')
transpiled_qc = transpile(qc, simulator)
transpiled_qc.draw('mpl')
# result_qc = execute(qc, backend=Aer.get_backend('qasm_simulator'), shots=8192).result()
# result_qc.get_counts()

# %%
transpiled_qc.data[5][0].name
# Out:
# 'cx'

# %%
result_qc = execute(transpiled_qc, backend=Aer.get_backend('qasm_simulator'), shots=8192).result()
result_qc.get_counts()
# Out:
# {'001111000': 1,
#  '111111100': 1,
#  '011001100': 1,
#  '010011101': 1,
#  '001111100': 2,
#  '000111111': 2,
#  '101101011': 1,
#  '010011000': 1,
#  '011000010': 1,
#  '111001010': 1,
#  '110111100': 1,
#  '000101100': 3,
#  '001010000': 3,
#  '010010111': 1,
#  '100110101': 3,
#  '100010010': 2,
#  '011110110': 2,
#  '110101111': 1,
#  '100000001': 2,
#  '011101011': 1,
#  '110110000': 1,
#  '010110111': 4,
#  '110011000': 1,
#  '010011001': 2,
#  '100111101': 2,
#  '100111001': 2,
#  '111110000': 1,
#  '010101111': 1,
#  '011001000': 3,
#  '001011001': 3,
#  '010010100': 3,
#  '011000000': 1,
#  '100111111': 2,
#  '001000000': 1,
#  '010011010': 1,
#  '111010001': 3,
#  '110100010': 2,
#  '010100000': 4,
#  '100110000': 2,
#  '110110100': 4,
#  '101010001': 3,
#  '100001100': 9,
#  '101110110': 1,
#  '111010000': 2,
#  '100011011': 2,
#  '011001001': 1,
#  '100010111': 1,
#  '110101011': 1,
#  '111110110': 3,
#  '111000001': 2,
#  '111101011': 2,
#  '011110101': 2,
#  '100010101': 3,
#  '100010100': 8,
#  '100100100': 2,
#  '100010110': 5,
#  '001110110': 4,
#  '111001000': 1,
#  '111011010': 1,
#  '001100001': 4,
#  '010101011': 2,
#  '111100101': 8,
#  '010101101': 3,
#  '101110011': 1,
#  '100110110': 8,
#  '100100000': 5,
#  '011110011': 14,
#  '111001101': 9,
#  '110000100': 9,
#  '101110010': 4,
#  '001101111': 6,
#  '100011010': 1,
#  '000111110': 7,
#  '010010011': 3,
#  '110011001': 5,
#  '100001011': 2,
#  '100100111': 2,
#  '110111110': 1,
#  '111101000': 9,
#  '100100011': 17,
#  '111101010': 4,
#  '110000111': 5,
#  '100010000': 2,
#  '011001011': 1,
#  '101101000': 10,
#  '001111011': 7,
#  '011100100': 1,
#  '110011011': 1,
#  '100101011': 11,
#  '010111000': 2,
#  '110001100': 2,
#  '000111000': 8,
#  '110110110': 4,
#  '110010100': 1,
#  '101001011': 3,
#  '100010001': 3,
#  '001100010': 2,
#  '110110011': 9,
#  '100000000': 3,
#  '001100101': 21,
#  '000110001': 8,
#  '010000010': 1,
#  '000100110': 1,
#  '001101010': 5,
#  '100011000': 3,
#  '111110101': 6,
#  '110000010': 2,
#  '010100110': 2,
#  '110100100': 3,
#  '010111111': 14,
#  '110000101': 10,
#  '001101110': 20,
#  '010111101': 3,
#  '101011110': 25,
#  '101001111': 13,
#  '010101110': 17,
#  '100001010': 19,
#  '101000010': 2,
#  '100010011': 1,
#  '001111111': 10,
#  '110100000': 2,
#  '101010101': 8,
#  '111111011': 7,
#  '001110111': 1,
#  '111000011': 7,
#  '010110101': 8,
#  '101000000': 25,
#  '001110001': 3,
#  '010001011': 3,
#  '010100111': 2,
#  '101110111': 8,
#  '010100011': 1,
#  '001100011': 43,
#  '000100010': 19,
#  '001010011': 14,
#  '010001111': 2,
#  '110011111': 2,
#  '010110100': 24,
#  '001100111': 6,
#  '111001100': 3,
#  '001011101': 4,
#  '101000001': 11,
#  '100101010': 1,
#  '101000111': 54,
#  '100101101': 7,
#  '100100010': 5,
#  '101111111': 41,
#  '111110001': 3,
#  '001001110': 18,
#  '001101100': 6,
#  '101001000': 3,
#  '111011000': 1,
#  '100110010': 6,
#  '010000100': 8,
#  '001001000': 1,
#  '100111010': 15,
#  '111100100': 29,
#  '110011110': 3,
#  '011001010': 4,
#  '100001111': 1,
#  '110111111': 1,
#  '000001100': 95,
#  '001000100': 10,
#  '100011110': 26,
#  '111000111': 19,
#  '111010101': 2,
#  '101011001': 42,
#  '101011010': 19,
#  '111000100': 22,
#  '110110010': 3,
#  '001010010': 2,
#  '000001111': 9,
#  '111101110': 11,
#  '011110100': 8,
#  '010100100': 2,
#  '000100100': 5,
#  '010001101': 6,
#  '111100001': 1,
#  '110111101': 2,
#  '010000000': 3,
#  '111010011': 20,
#  '110001001': 18,
#  '101101100': 8,
#  '000010011': 50,
#  '101101110': 27,
#  '010001110': 16,
#  '100100101': 2,
#  '100000010': 8,
#  '000011101': 21,
#  '010110011': 8,
#  '001110101': 2,
#  '010111001': 42,
#  '101111001': 80,
#  '000100111': 21,
#  '100101100': 2,
#  '110001010': 4,
#  '001001001': 23,
#  '001010100': 3,
#  '001111001': 22,
#  '101110100': 25,
#  '101011000': 3,
#  '000010111': 15,
#  '000001101': 7,
#  '101011101': 3,
#  '111010100': 16,
#  '000000001': 5,
#  '101111011': 28,
#  '000010001': 35,
#  '111100010': 9,
#  '111011001': 17,
#  '101111000': 11,
#  '101000101': 25,
#  '101100101': 25,
#  '101111100': 2,
#  '000000100': 412,
#  '001111101': 16,
#  '000010101': 33,
#  '101001101': 38,
#  '000111001': 59,
#  '000011010': 1,
#  '000001001': 572,
#  '101010110': 6,
#  '001000111': 12,
#  '111001001': 42,
#  '100011001': 26,
#  '101001110': 93,
#  '001001101': 9,
#  '100110011': 63,
#  '110111010': 2,
#  '000111011': 9,
#  '000101110': 138,
#  '101010010': 3,
#  '111110010': 3,
#  '000111100': 4,
#  '000110010': 68,
#  '100001000': 14,
#  '111000101': 13,
#  '000111101': 17,
#  '000010000': 20,
#  '110101101': 2,
#  '010100101': 1,
#  '000110101': 34,
#  '111000000': 11,
#  '111110011': 3,
#  '100011101': 1,
#  '101111110': 145,
#  '011000101': 2,
#  '100000110': 4,
#  '100011111': 13,
#  '011111010': 3,
#  '111100011': 39,
#  '000000010': 65,
#  '000010110': 32,
#  '010010000': 1,
#  '000011000': 36,
#  '000001011': 34,
#  '110000110': 1,
#  '000000110': 67,
#  '001100100': 38,
#  '101110101': 12,
#  '000110000': 40,
#  '001001111': 4,
#  '000101001': 59,
#  '001010110': 3,
#  '111111101': 13,
#  '100000011': 40,
#  '111111111': 13,
#  '101000100': 35,
#  '001110010': 3,
#  '111110111': 2,
#  '010011110': 2,
#  '001100110': 11,
#  '101100110': 12,
#  '101110001': 20,
#  '000000111': 36,
#  '111101001': 20,
#  '101100011': 82,
#  '000101010': 2,
#  '000011110': 135,
#  '100000100': 71,
#  '101111101': 27,
#  '111111001': 22,
#  '100000111': 8,
#  '001101001': 36,
#  '000010100': 1,
#  '000111010': 84,
#  '000001000': 141,
#  '000000101': 173,
#  '000100000': 20,
#  '101001001': 59,
#  '000110011': 595,
#  '100101111': 2,
#  '000000000': 3,
#  '000011111': 51,
#  '000101101': 70,
#  '111111000': 2,
#  '010000101': 4,
#  '001000101': 4,
#  '000001110': 121,
#  '001101000': 5,
#  '000100011': 46,
#  '110100011': 5,
#  '010010001': 2,
#  '101101001': 78,
#  '111001111': 6,
#  '101010100': 61,
#  '000001010': 164,
#  '001101011': 1,
#  '000101111': 25,
#  '101100111': 5,
#  '010101001': 11,
#  '101100001': 2,
#  '000011001': 131,
#  '100110100': 32,
#  '101011111': 4,
#  '010111110': 54,
#  '111101100': 9,
#  '110001000': 6,
#  '010111011': 12,
#  '110001110': 6,
#  '000110110': 56,
#  '101011011': 5,
#  '001011010': 8,
#  '010000111': 12,
#  '100101110': 13,
#  '100001110': 28,
#  '110000011': 11,
#  '111100111': 2,
#  '010001001': 14,
#  '010111010': 4,
#  '100001001': 81,
#  '011110000': 2,
#  '111100110': 7,
#  '000101011': 47,
#  '001111110': 56,
#  '000011011': 4,
#  '101101111': 2,
#  '111011110': 12,
#  '011000011': 5,
#  '010110001': 5,
#  '100000101': 17,
#  '111010010': 1,
#  '011101110': 1,
#  '101101010': 19,
#  '000110100': 316,
#  '111001110': 31,
#  '111111110': 47,
#  '110101100': 1,
#  '000000011': 439,
#  '000010010': 17,
#  '101100010': 9,
#  '101100100': 87,
#  '101010000': 15,
#  '011000100': 4,
#  '101010011': 94}

# %%
qc = QuantumCircuit.from_qasm_file('../limited_quantum_circuits/realamprandom_indep_qiskit_9.qasm')
transpiled_qc = transpile(qc, simulator)
mutation_qc = mutate_circuit(transpiled_qc, 4, quantum_gates)
# Out:
# crx [5.72383078245412]

# %%
mutation_qc.draw('mpl')

# %%
result_mutation_qc = execute(mutation_qc, backend=Aer.get_backend('qasm_simulator'), shots=8192).result()
result_mutation_qc.get_counts()
# Out:
# {'000': 8192}

# %%
file = '../limited_quantum_circuits/qpeexact_indep_qiskit_4.qasm'
reconstructed_mutation_qc = generate_monitoring_circuit(mutation_qc, file, res, 3)

# %%
reconstructed_mutation_qc.draw('mpl')

# %%
result_reconstructed_mutation_qc = execute(reconstructed_mutation_qc, backend=Aer.get_backend('qasm_simulator'), shots=8192).result()
# result_reconstructed_mutation_qc.get_counts()
e_t_o = {}
for k, v in result_reconstructed_mutation_qc.get_counts().items():
    if k.split(' ')[0] not in e_t_o:
        e_t_o[k.split(' ')[0]] = []
    e_t_o[k.split(' ')[0]].append({k.split(' ')[1] : v})
e_t_o
# new_counts = defaultdict(int)  # 使用defaultdict方便累加重复结果
# for k, v in result_reconstructed_mutation_qc.get_counts().items():
#     new_key = k.split(' ')[0]  
#     new_counts[new_key] += v  # 合并相同的结果
# dict(new_counts)
# Out:
# {'001': [{'000': 8192}]}

# %%
# generate_monitoring_circuit('../quantum circuits/grover-noancilla_indep_qiskit_3.qasm', res, num=1000).draw('mpl')
reconstructed_qc = comparison_circuit['../limited_quantum_circuits/qpeexact_indep_qiskit_4.qasm']
reconstructed_qc.draw('mpl')

# %%
result_reconstructed_qc = execute(reconstructed_qc, backend=Aer.get_backend('qasm_simulator'), shots=8192).result()
# result_reconstructed_qc.get_counts()
e_t_o = {}
for k, v in result_reconstructed_qc.get_counts().items():
    if k.split(' ')[0] not in e_t_o:
        e_t_o[k.split(' ')[0]] = []
    e_t_o[k.split(' ')[0]].append({k.split(' ')[1] : v})
e_t_o
# new_counts = defaultdict(int)  # 使用defaultdict方便累加重复结果
# for k, v in result_reconstructed_qc.get_counts().items():
#     new_key = k.split(' ')[0]  
#     new_counts[new_key] += v  # 合并相同的结果
# dict(new_counts)
# Out:
# {'001': [{'100': 8192}]}

# %%
result_reconstructed_qc.get_counts()
# Out:
# {'0010111111 1111': 41,
#  '1110111111 0111': 132,
#  '1110111111 1111': 24,
#  '0110111111 0101': 80,
#  '1110111111 0101': 88,
#  '0110111111 0111': 104,
#  '0110111111 1101': 75,
#  '1110111111 1101': 82,
#  '0110111111 1111': 27,
#  '1110111111 1011': 736,
#  '0010111111 0011': 255,
#  '0010111111 0101': 132,
#  '0010111111 1101': 144,
#  '1110111111 0011': 126,
#  '0010111111 0111': 244,
#  '0110111111 1011': 756,
#  '0110111111 1001': 865,
#  '0010111111 1001': 1746,
#  '1110111111 1001': 865,
#  '0010111111 1011': 1512,
#  '0110111111 0011': 158}

# %%
file = '../quantum_circuits/qpeinexact_indep_qiskit_10.qasm'
get_possible_outputs(file, unblanced_circuit_list)
# Out:
# /var/folders/07/mn1lw68s3d903fldy_g4tqmm0000gn/T/ipykernel_66115/448901860.py:24: DeprecationWarning: The return type of saved statevectors has been changed from a `numpy.ndarray` to a `qiskit.quantum_info.Statevector` as of qiskit-aer 0.10. Accessing numpy array attributes is deprecated and will result in an error in a future release. To continue using saved result objects as arrays you can explicitly cast them using  `np.asarray(object)`.
#   for idx, amplitude in enumerate(statevector):
# ['111000001',
#  '100011011',
#  '010010100',
#  '110110000',
#  '110011011',
#  '110010110',
#  '100101100',
#  '011011110',
#  '111110000',
#  '001001001',
#  '100101111',
#  '100010001',
#  '111110101',
#  '100011101',
#  '110001100',
#  '011000001',
#  '010110110',
#  '111110100',
#  '011000000',
#  '011001011',
#  '101010001',
#  '011011000',
#  '111111111',
#  '001001101',
#  '110110101',
#  '010011001',
#  '001100111',
#  '110010101',
#  '101101101',
#  '100001000',
#  '101010101',
#  '011100110',
#  '100010011',
#  '100011000',
#  '111010010',
#  '100100111',
#  '010000101',
#  '101010000',
#  '101100101',
#  '001000011',
#  '001111100',
#  '000100011',
#  '110101001',
#  '100111000',
#  '100110110',
#  '110101110',
#  '001001110',
#  '000011111',
#  '111010111',
#  '000001101',
#  '110110111',
#  '111001101',
#  '011010111',
#  '001101111',
#  '001110101',
#  '100100101',
#  '011110110',
#  '010001100',
#  '011000011',
#  '001001100',
#  '101110011',
#  '101101110',
#  '001011101',
#  '010110011',
#  '010001111',
#  '101001010',
#  '011100111',
#  '110010001',
#  '010101101',
#  '011011101',
#  '100101110',
#  '111010000',
#  '101001111',
#  '001010101',
#  '011010010',
#  '100111101',
#  '110000110',
#  '001001011',
#  '001101101',
#  '001110111',
#  '110001111',
#  '111101000',
#  '011000010',
#  '010111110',
#  '100101011',
#  '010100111',
#  '110000111',
#  '111000100',
#  '011001111',
#  '000010010',
#  '001011010',
#  '010010011',
#  '011100010',
#  '010111000',
#  '000010111',
#  '100000001',
#  '100110010',
#  '111011001',
#  '010001011',
#  '100000011',
#  '100010101',
#  '101000011',
#  '001111111',
#  '100100001',
#  '111011010',
#  '011110010',
#  '001011110',
#  '011011100',
#  '001101011',
#  '100000100',
#  '010011011',
#  '010011101',
#  '001111000',
#  '010101001',
#  '100100100',
#  '010100011',
#  '111101001',
#  '111100001',
#  '110011001',
#  '100011010',
#  '111111011',
#  '000000001',
#  '000100101',
#  '101000101',
#  '111000011',
#  '000100100',
#  '001000100',
#  '000111111',
#  '100001011',
#  '000000101',
#  '011111100',
#  '011001010',
#  '101110000',
#  '010011111',
#  '100011111',
#  '110010011',
#  '001011100',
#  '111000110',
#  '000110010',
#  '001100000',
#  '010110101',
#  '100001111',
#  '011010000',
#  '000101011',
#  '110100000',
#  '110000001',
#  '001000110',
#  '011110111',
#  '001101000',
#  '101111000',
#  '111100110',
#  '000001001',
#  '101101000',
#  '101101001',
#  '001111110',
#  '011000100',
#  '001100001',
#  '101110001',
#  '101110110',
#  '100111010',
#  '001010111',
#  '000001010',
#  '011101010',
#  '101000110',
#  '011000110',
#  '110001001',
#  '101111110',
#  '101011100',
#  '111101101',
#  '001000010',
#  '011101000',
#  '000011110',
#  '010010110',
#  '000111001',
#  '010101111',
#  '101010111',
#  '000001100',
#  '101010010',
#  '000110100',
#  '000110001',
#  '010011000',
#  '010111100',
#  '000101001',
#  '011101100',
#  '111110010',
#  '010010101',
#  '100110011',
#  '101011001',
#  '111111101',
#  '011001001',
#  '111101010',
#  '101001001',
#  '011101001',
#  '111100010',
#  '110000000',
#  '010110000',
#  '010000100',
#  '111010001',
#  '101001101',
#  '101010011',
#  '001110110',
#  '101110100',
#  '001011111',
#  '010111011',
#  '000010100',
#  '001011001',
#  '010111111',
#  '110101011',
#  '010000011',
#  '001010110',
#  '001100110',
#  '100001110',
#  '110110110',
#  '001000101',
#  '101101011',
#  '101000100',
#  '111111001',
#  '111001011',
#  '001111101',
#  '100101000',
#  '010110100',
#  '011001110',
#  '101011000',
#  '100010010',
#  '011010101',
#  '000000110',
#  '000000010',
#  '001001010',
#  '100110111',
#  '010111010',
#  '000110111',
#  '011111101',
#  '001010100',
#  '011100101',
#  '001001111',
#  '110110100',
#  '110001011',
#  '101111100',
#  '011000111',
#  '110100011',
#  '101000001',
#  '011110001',
#  '111100101',
#  '000101101',
#  '011101111',
#  '101011010',
#  '110010111',
#  '010000010',
#  '001010010',
#  '111010101',
#  '011110101',
#  '101101111',
#  '011111001',
#  '110111110',
#  '010001010',
#  '110101111',
#  '001111011',
#  '101101010',
#  '101110010',
#  '100010100',
#  '010001101',
#  '011011111',
#  '110111011',
#  '111011100',
#  '000100010',
#  '001100011',
#  '100100000',
#  '110101010',
#  '101000111',
#  '101110101',
#  '111010011',
#  '001100101',
#  '010010010',
#  '011010011',
#  '110100001',
#  '011010100',
#  '110011010',
#  '111111010',
#  '101000010',
#  '110111001',
#  '111110011',
#  '000110011',
#  '001111010',
#  '001101001',
#  '000011011',
#  '010000000',
#  '001101110',
#  '011100100',
#  '010101100',
#  '110000011',
#  '100101010',
#  '000001111',
#  '100100110',
#  '011010001',
#  '111100111',
#  '110011000',
#  '110100111',
#  '100110100',
#  '011101011',
#  '000101110',
#  '111011000',
#  '001010011',
#  '010100010',
#  '101100001',
#  '000111110',
#  '111111110',
#  '010110010',
#  '101000000',
#  '111011110',
#  '001011011',
#  '110100100',
#  '111110110',
#  '111101100',
#  '010100001',
#  '010100110',
#  '101111001',
#  '110010000',
#  '110111111',
#  '011011011',
#  '000101010']

# %%
with open('../data/execution_result.pkl', 'rb') as file:
    execution_result = pickle.load(file)
for er in execution_result:
    actual_result_list = list(list(er[0].items())[0][1][1].keys())
    print(list(er[0].items())[0][0], actual_result_list)
# Out:
# ../limited quantum circuits/twolocalrandom_indep_qiskit_3.qasm ['001', '101', '100', '110', '010', '111', '000', '011']
# ../limited quantum circuits/qpeexact_indep_qiskit_5.qasm ['1111', '1001', '1011', '0011', '1101', '0111', '0101']
# ../limited quantum circuits/su2random_indep_qiskit_4.qasm ['1110', '1001', '0000', '0011', '0111', '1010', '1111', '0001', '1000', '0110', '0100', '1011', '0101', '1100', '0010', '1101']
# ../limited quantum circuits/su2random_indep_qiskit_8.qasm ['00001011', '10110101', '00011011', '10110111', '10011100', '10100110', '00100001', '01111001', '01110001', '10110001', '00001101', '00011000', '01011001', '10101110', '01011000', '10100000', '00101001', '00010111', '10001010', '01000011', '11010100', '00011111', '00100110', '11111001', '01011011', '01001011', '11110101', '00111100', '10001001', '01100100', '00100000', '00011001', '11101001', '00100111', '10101001', '10111001', '10000001', '00011110', '10011000', '10010111', '11010011', '00010100', '11001001', '10110000', '00101111', '11011110', '10000100', '11000001', '00110110', '11000101', '10010100', '01110100', '10010000', '10111011', '00110101', '10100001', '11
', '001010010', '100110111', '100010110', '100101101', '101000001', '010010110', '100111111', '010101000', '010101010', '011100011', '100011101', '100100100', '100011000', '010100110', '100101100', '001100011', '111101000', '101000010', '010100010', '100000011', '011100111', '011101011', '100011001', '100100000', '110100010', '010011111', '010011011', '101111001', '111101111', '111010111', '100101110', '110101000', '110101010', '101000111', '111100011', '100000001', '100011111', '011101101', '101000100', '011011000', '001110001', '011001001', '101110111', '100011010', '100111101', '011011111', '001101001', '101010110', '100111110', '100110001', '110001101', '111100010', '011011101', '010100000', '011110001', '111011001', '001101110', '001110011', '010111001', '100010010']
# ../limited quantum circuits/vqe_indep_qiskit_5.qasm ['11010', '01011', '00110', '01110', '11001', '11011', '11000', '11110', '10110']
# ../limited quantum circuits/qpeinexact_indep_qiskit_3.qasm ['10', '01', '00', '11']
# ../limited quantum circuits/su2random_indep_qiskit_7.qasm ['0110110', '1101100', '1010110', '0101101', '0010000', '1110101', '1011111', '0000010', '1010100', '1000000', '1111010', '1110111', '1000101', '1101101', '1000010', '0101011', '0100111', '0001111', '1111001', '0011110', '0111100', '0100010', '0000111', '1010000', '1011101', '0001010', '1110000', '1010011', '0000101', '1010001', '0000011', '1101111', '0001101', '0110001', '0011100', '0100101', '1110010', '0001001', '1000001', '0001011', '1111110', '0110111', '1101110', '1011010', '1011000', '0111001', '1011011', '0111110', '0100100', '1010101', '1101010', '0100011', '0010111', '0011011', '0011000', '1100100', '0010100', '1001011', '0101010', '0000110', '0001110', '0110101', '0000000', '0100001', '1101000', '0110010', '0010101', '0010011', '1110110', '1000111', '0101110', '0101000', '0011101', '0111000', '0110011', '1111100', '1001010', '1001101', '0101001', '1111011', '1111000', '1100001', '0110000', '1100101', '0110100', '1101001', '0111011', '0001100', '0010001', '0000100', '0010110', '1010111', '1001100', '0111111', '0011010', '1001001', '1100010', '1110100', '1011100', '1111111', '1100111', '1010010', '1100000', '0011111', '0101111', '0111101', '0000001', '0011001', '0010010', '1110011', '1101011', '1110001', '0100000', '0001000', '1001111', '1000110', '1100110', '0101100', '1001110', '1000011', '1001000', '0100110', '1100011', '1011110', '1111101', '1011001']
# ../limited quantum circuits/realamprandom_indep_qiskit_2.qasm ['01', '11', '00', '10']
# ../limited quantum circuits/vqe_indep_qiskit_9.qasm ['111110110', '100101101', '101110100', '101011000', '101111100', '101101100', '111001000', '101001001', '101111000', '101011100', '101101001', '101000101', '101101101', '100001101', '101000000', '101001100', '101101000', '101001101', '101001000', '111110010']

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram, plot_state_city
import qiskit.quantum_info as qi

# %%
AerSimulator().available_methods()
# Out:
# ('automatic',
#  'statevector',
#  'density_matrix',
#  'stabilizer',
#  'matrix_product_state',
#  'extended_stabilizer',
#  'unitary',
#  'superop')

# %%
with open('../data/execution_result.pkl', 'rb') as file:
    execution_result = pickle.load(file)
for er in execution_result:
    flag = False
    for k in list(list(er[0].items())[0][1][1].keys()):
        if ' ' in k:
            flag = True
    if flag:
        print(list(er[0].items())[0][1])

# %%
result['../limited_quantum_circuits/qpeinexact_indep_qiskit_3.qasm']
# Out:
# [[0,
#   'h',
#   BitLocations(index=0, registers=[(QuantumRegister(2, 'q'), 0)]),
#   0.5000000000000001,
#   0.4999999999999999,
#   [],
#   None],
#  [1,
#   'h',
#   BitLocations(index=1, registers=[(QuantumRegister(2, 'q'), 1)]),
#   0.5000000000000001,
#   0.4999999999999999,
#   [],
#   None],
#  [2,
#   'x',
#   BitLocations(index=2, registers=[(QuantumRegister(1, 'psi'), 0)]),
#   0.0,
#   1.0,
#   [],
#   None],
#  [3,
#   'measure',
#   BitLocations(index=2, registers=[(QuantumRegister(1, 'psi'), 0)]),
#   0.0,
#   1.0,
#   [],
#   None],
#  [4,
#   'reset',
#   BitLocations(index=2, registers=[(QuantumRegister(1, 'psi'), 0)]),
#   1.0,
#   0.0,
#   [],
#   None],
#  [5,
#   'x',
#   BitLocations(index=2, registers=[(QuantumRegister(1, 'psi'), 0)]),
#   0.0,
#   1.0,
#   [],
#   'test_2'],
#  [6,
#   'cp',
#   BitLocations(index=2, registers=[(QuantumRegister(1, 'psi'), 0)]),
#   0.0,
#   1.0,
#   [2.356194490192345],
#   None],
#  [6,
#   'cp',
#   BitLocations(index=0, registers=[(QuantumRegister(2, 'q'), 0)]),
#   0.5000000000000001,
#   0.4999999999999999,
#   [2.356194490192345],
#   None],
#  [7,
#   'measure',
#   BitLocations(index=2, registers=[(QuantumRegister(1, 'psi'), 0)]),
#   0.0,
#   1.0,
#   [],
#   None],
#  [8,
#   'reset',
#   BitLocations(index=2, registers=[(QuantumRegister(1, 'psi'), 0)]),
#   1.0,
#   0.0,
#   [],
#   None],
#  [9,
#   'x',
#   BitLocations(index=2, registers=[(QuantumRegister(1, 'psi'), 0)]),
#   0.0,
#   1.0,
#   [],
#   'test_3'],
#  [10,
#   'cp',
#   BitLocations(index=2, registers=[(QuantumRegister(1, 'psi'), 0)]),
#   0.0,
#   1.0,
#   [-1.5707963267948966],
#   None],
#  [10,
#   'cp',
#   BitLocations(index=1, registers=[(QuantumRegister(2, 'q'), 1)]),
#   0.5000000000000001,
#   0.4999999999999999,
#   [-1.5707963267948966],
#   None],
#  [11,
#   'swap',
#   BitLocations(index=0, registers=[(QuantumRegister(2, 'q'), 0)]),
#   0.5000000000000001,
#   0.4999999999999999,
#   [],
#   None],
#  [11,
#   'swap',
#   BitLocations(index=1, registers=[(QuantumRegister(2, 'q'), 1)]),
#   0.5000000000000001,
#   0.4999999999999999,
#   [],
#   None],
#  [12,
#   'h',
#   BitLocations(index=0, registers=[(QuantumRegister(2, 'q'), 0)]),
#   0.49999999999999994,
#   0.5,
#   [],
#   None],
#  [13,
#   'cp',
#   BitLocations(index=1, registers=[(QuantumRegister(2, 'q'), 1)]),
#   0.5,
#   0.49999999999999994,
#   [-1.5707963267948966],
#   None],
#  [13,
#   'cp',
#   BitLocations(index=0, registers=[(QuantumRegister(2, 'q'), 0)]),
#   0.49999999999999994,
#   0.5,
#   [-1.5707963267948966],
#   None],
#  [14,
#   'h',
#   BitLocations(index=1, registers=[(QuantumRegister(2, 'q'), 1)]),
#   0.5,
#   0.49999999999999994,
#   [],
#   None]]

# %%
unexpected_result_list
# Out:
# ['../limited quantum circuits/qpeexact_indep_qiskit_5.qasm',
#  '../limited quantum circuits/grover-v-chain_indep_qiskit_3.qasm',
#  '../limited quantum circuits/routing_indep_qiskit_2.qasm',
#  '../limited quantum circuits/tsp_indep_qiskit_4.qasm',
#  '../limited quantum circuits/qpeinexact_indep_qiskit_9.qasm',
#  '../limited quantum circuits/grover-noancilla_indep_qiskit_3.qasm',
#  '../limited quantum circuits/qpeinexact_indep_qiskit_10.qasm']

# %%
ratio_sum = 0
max_ratio = 0
min_ratio = 1
max_key = ''
min_key = ''

for key, value in res.items():
    qc = pm.run(QuantumCircuit.from_qasm_file(key))
    ratio = len(value) / len(qc.data)
    if ratio > max_ratio:
        max_ratio = ratio
        max_key = key
    if ratio < min_ratio:
        min_ratio = ratio
        min_key = key
    ratio_sum += ratio

average_ratio = ratio_sum / len(res)
print('average_ratio', average_ratio)
print('max_ratio', max_ratio)
print('max_key', max_key)
print('min_ratio', min_ratio)
print('min_key', min_key)
# Out:
# average_ratio 0.25168086523506183
# max_ratio 0.8636363636363636
# max_key ../quantum circuits/qft_indep_qiskit_20.qasm
# min_ratio 0.012195121951219513
# min_key ../quantum circuits/su2random_indep_qiskit_12.qasm

# %%
ratio_sum = 0
max_ratio = 0
min_ratio = 1
max_key = ''
min_key = ''

for key, value in res_new.items():
    qc = pm.run(QuantumCircuit.from_qasm_file(key))
    ratio = len(value) / len(qc.data)
    if ratio > max_ratio:
        max_ratio = ratio
        max_key = key
    if ratio < min_ratio:
        min_ratio = ratio
        min_key = key
    ratio_sum += ratio

average_ratio = ratio_sum / len(res_new)
print('average_ratio', average_ratio)
print('max_ratio', max_ratio)
print('max_key', max_key)
print('min_ratio', min_ratio)
print('min_key', min_key)
# Out:
# average_ratio 0.15278208456025322
# max_ratio 0.5
# max_key ../quantum circuits/qft_indep_qiskit_4.qasm
# min_ratio 0.012195121951219513
# min_key ../quantum circuits/su2random_indep_qiskit_12.qasm

# %%
bad_qc_list = [
    "../quantum circuits/qpeexact_indep_qiskit_5.qasm",
    "../quantum circuits/grover-v-chain_indep_qiskit_3.qasm",
    "../quantum circuits/qpeinexact_indep_qiskit_12.qasm",
    "../quantum circuits/qpeinexact_indep_qiskit_9.qasm",
    "../quantum circuits/qpeinexact_indep_qiskit_10.qasm",
    "../quantum circuits/grover-noancilla_indep_qiskit_3.qasm"
]

# %%
for key, value in res_new.items():
    if key not in bad_qc_list:
        continue
    qc = pm.run(QuantumCircuit.from_qasm_file(key))
    ratio = len(value) / len(qc.data)
    valid_num = 0
    for i in result[key]:
        if (i[-1] and i[-1].split('_')[0] == 'test') and i[2][1][0][0].name != 'eq':
            if i[3] < 0.99 and i[4] < 0.99:
                # print(i)
                continue
            valid_num += 1
    valid_ratio_whole = valid_num / len(qc.data)
    valid_ratio_monitor = valid_num / len(value)

    print(key, ratio, valid_ratio_whole, valid_ratio_monitor)
# Out:
# ../quantum circuits/qpeexact_indep_qiskit_5.qasm 0.47619047619047616 0.3333333333333333 0.7
# ../quantum circuits/grover-v-chain_indep_qiskit_3.qasm 0.3076923076923077 0.23076923076923078 0.75
# ../quantum circuits/qpeinexact_indep_qiskit_12.qasm 0.18085106382978725 0.11702127659574468 0.6470588235294118
# ../quantum circuits/qpeinexact_indep_qiskit_9.qasm 0.15789473684210525 0.14035087719298245 0.8888888888888888
# ../quantum circuits/grover-noancilla_indep_qiskit_3.qasm 0.3076923076923077 0.23076923076923078 0.75
# ../quantum circuits/qpeinexact_indep_qiskit_10.qasm 0.17647058823529413 0.1323529411764706 0.75

# %%
for key, value in res_new.items():
    qc = QuantumCircuit.from_qasm_file(key)
    transpiled_qc = transpile(qc, simulator)
    for v in value:
        if v[1] != transpiled_qc.data[v[0]][0].name:
            print(key, v[0])
# Out:
# ../limited quantum circuits/random_indep_qiskit_6.qasm 12
# ../limited quantum circuits/random_indep_qiskit_6.qasm 12
# ../limited quantum circuits/random_indep_qiskit_6.qasm 29
# ../limited quantum circuits/random_indep_qiskit_6.qasm 31

# %%
from pathlib import Path
import shutil
import re

# 定义原始文件夹和目标文件夹
source_folder = Path("../quantum circuits")
destination_folder = Path("../limited_quantum_circuits")

# 确保目标文件夹存在
destination_folder.mkdir(parents=True, exist_ok=True)

# 正则匹配文件名中的 qubit 数量
pattern = re.compile(r"_(\d+)\.qasm$")

# 遍历文件夹，筛选符合条件的 .qasm 文件
for file in source_folder.glob("*.qasm"):
    match = pattern.search(file.name)
    if match:
        qubit_count = int(match.group(1))  # 提取 qubit 数量
        # print(file, qubit_count)
        if qubit_count <= 10:  # 只复制不超过 10 个 qubit 的文件
            shutil.copy(file, destination_folder / file.name)
            print(f"复制文件: {file.name} 到 {destination_folder}")
# Out:
# 复制文件: qnn_indep_qiskit_8.qasm 到 ../limited quantum circuits
# 复制文件: qaoa_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: ghz_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: portfoliovqe_indep_qiskit_8.qasm 到 ../limited quantum circuits
# 复制文件: twolocalrandom_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: qpeexact_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: su2random_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: ae_indep_qiskit_8.qasm 到 ../limited quantum circuits
# 复制文件: qnn_indep_qiskit_10.qasm 到 ../limited quantum circuits
# 复制文件: qftentangled_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: qnn_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: graphstate_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: ghz_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: dj_indep_qiskit_10.qasm 到 ../limited quantum circuits
# 复制文件: qft_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: qpeexact_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: portfoliovqe_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: su2random_indep_qiskit_8.qasm 到 ../limited quantum circuits
# 复制文件: dj_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: realamprandom_indep_qiskit_10.qasm 到 ../limited quantum circuits
# 复制文件: ae_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: random_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: vqe_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: grover-v-chain_indep_qiskit_2.qasm 到 ../limited quantum circuits
# 复制文件: graphstate_indep_qiskit_10.qasm 到 ../limited quantum circuits
# 复制文件: twolocalrandom_indep_qiskit_10.qasm 到 ../limited quantum circuits
# 复制文件: grover-v-chain_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: ae_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: vqe_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: random_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: su2random_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: dj_indep_qiskit_2.qasm 到 ../limited quantum circuits
# 复制文件: portfoliovqe_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: qpeexact_indep_qiskit_8.qasm 到 ../limited quantum circuits
# 复制文件: qft_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: ghz_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: qnn_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: qftentangled_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: qftentangled_indep_qiskit_10.qasm 到 ../limited quantum circuits
# 复制文件: ae_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: su2random_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: twolocalrandom_indep_qiskit_2.qasm 到 ../limited quantum circuits
# 复制文件: qpeexact_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: portfoliovqe_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: vqe_indep_qiskit_10.qasm 到 ../limited quantum circuits
# 复制文件: ghz_indep_qiskit_8.qasm 到 ../limited quantum circuits
# 复制文件: qnn_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: qaoa_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: qnn_indep_qiskit_2.qasm 到 ../limited quantum circuits
# 复制文件: graphstate_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: ghz_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: twolocalrandom_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: dj_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: ae_indep_qiskit_2.qasm 到 ../limited quantum circuits
# 复制文件: grover-v-chain_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: qpeinexact_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: graphstate_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: portfolioqaoa_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: twolocalrandom_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: qpeexact_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: su2random_indep_qiskit_2.qasm 到 ../limited quantum circuits
# 复制文件: dj_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: realamprandom_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: grover-v-chain_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: realamprandom_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: portfoliovqe_indep_qiskit_10.qasm 到 ../limited quantum circuits
# 复制文件: su2random_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: dj_indep_qiskit_8.qasm 到 ../limited quantum circuits
# 复制文件: twolocalrandom_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: qpeexact_indep_qiskit_2.qasm 到 ../limited quantum circuits
# 复制文件: portfolioqaoa_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: grover-noancilla_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: graphstate_indep_qiskit_8.qasm 到 ../limited quantum circuits
# 复制文件: qpeinexact_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: grover-v-chain_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: ae_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: dj_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: portfoliovqe_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: twolocalrandom_indep_qiskit_8.qasm 到 ../limited quantum circuits
# 复制文件: ghz_indep_qiskit_2.qasm 到 ../limited quantum circuits
# 复制文件: graphstate_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: random_indep_qiskit_10.qasm 到 ../limited quantum circuits
# 复制文件: qft_indep_qiskit_10.qasm 到 ../limited quantum circuits
# 复制文件: qnn_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: qpeinexact_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: realamprandom_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: random_indep_qiskit_2.qasm 到 ../limited quantum circuits
# 复制文件: dj_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: portfolioqaoa_indep_qiskit_8.qasm 到 ../limited quantum circuits
# 复制文件: qft_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: graphstate_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: qpeinexact_indep_qiskit_8.qasm 到 ../limited quantum circuits
# 复制文件: qftentangled_indep_qiskit_2.qasm 到 ../limited quantum circuits
# 复制文件: realamprandom_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: twolocalrandom_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: portfolioqaoa_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: grover-noancilla_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: qaoa_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: grover-noancilla_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: portfolioqaoa_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: su2random_indep_qiskit_10.qasm 到 ../limited quantum circuits
# 复制文件: qpeexact_indep_qiskit_10.qasm 到 ../limited quantum circuits
# 复制文件: twolocalrandom_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: realamprandom_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: qftentangled_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: qpeinexact_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: ghz_indep_qiskit_10.qasm 到 ../limited quantum circuits
# 复制文件: graphstate_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: portfolioqaoa_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: qft_indep_qiskit_2.qasm 到 ../limited quantum circuits
# 复制文件: dj_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: random_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: vqe_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: portfolioqaoa_indep_qiskit_10.qasm 到 ../limited quantum circuits
# 复制文件: realamprandom_indep_qiskit_8.qasm 到 ../limited quantum circuits
# 复制文件: grover-v-chain_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: qpeinexact_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: qftentangled_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: random_indep_qiskit_8.qasm 到 ../limited quantum circuits
# 复制文件: vqe_indep_qiskit_8.qasm 到 ../limited quantum circuits
# 复制文件: realamprandom_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: ae_indep_qiskit_10.qasm 到 ../limited quantum circuits
# 复制文件: su2random_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: qpeexact_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: qft_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: grover-noancilla_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: qaoa_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: qpeinexact_indep_qiskit_2.qasm 到 ../limited quantum circuits
# 复制文件: qftentangled_indep_qiskit_8.qasm 到 ../limited quantum circuits
# 复制文件: vqe_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: random_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: ae_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: qaoa_indep_qiskit_10.qasm 到 ../limited quantum circuits
# 复制文件: portfoliovqe_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: qft_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: ghz_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: qaoa_indep_qiskit_8.qasm 到 ../limited quantum circuits
# 复制文件: qnn_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: qaoa_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: qnn_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: ghz_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: qft_indep_qiskit_4.qasm 到 ../limited quantum circuits
# 复制文件: portfoliovqe_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: qpeinexact_indep_qiskit_10.qasm 到 ../limited quantum circuits
# 复制文件: random_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: vqe_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: ae_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: qftentangled_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: qpeinexact_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: grover-noancilla_indep_qiskit_2.qasm 到 ../limited quantum circuits
# 复制文件: qaoa_indep_qiskit_5.qasm 到 ../limited quantum circuits
# 复制文件: portfolioqaoa_indep_qiskit_3.qasm 到 ../limited quantum circuits
# 复制文件: qft_indep_qiskit_8.qasm 到 ../limited quantum circuits
# 复制文件: qpeexact_indep_qiskit_6.qasm 到 ../limited quantum circuits
# 复制文件: su2random_indep_qiskit_7.qasm 到 ../limited quantum circuits
# 复制文件: realamprandom_indep_qiskit_2.qasm 到 ../limited quantum circuits
# 复制文件: vqe_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: random_indep_qiskit_9.qasm 到 ../limited quantum circuits
# 复制文件: qftentangled_indep_qiskit_5.qasm 到 ../limited quantum circuits

# %%
for key in res_new:
    print(key)
# Out:
# ../limited quantum circuits/twolocalrandom_indep_qiskit_3.qasm
# ../limited quantum circuits/qpeexact_indep_qiskit_5.qasm
# ../limited quantum circuits/su2random_indep_qiskit_4.qasm
# ../limited quantum circuits/su2random_indep_qiskit_8.qasm
# ../limited quantum circuits/realamprandom_indep_qiskit_10.qasm
# ../limited quantum circuits/vqe_indep_qiskit_6.qasm
# ../limited quantum circuits/twolocalrandom_indep_qiskit_10.qasm
# ../limited quantum circuits/grover-v-chain_indep_qiskit_3.qasm
# ../limited quantum circuits/vqe_indep_qiskit_7.qasm
# ../limited quantum circuits/su2random_indep_qiskit_9.qasm
# ../limited quantum circuits/portfoliovqe_indep_qiskit_5.qasm
# ../limited quantum circuits/routing_indep_qiskit_2.qasm
# ../limited quantum circuits/su2random_indep_qiskit_5.qasm
# ../limited quantum circuits/twolocalrandom_indep_qiskit_2.qasm
# ../limited quantum circuits/qpeexact_indep_qiskit_4.qasm
# ../limited quantum circuits/vqe_indep_qiskit_10.qasm
# ../limited quantum circuits/twolocalrandom_indep_qiskit_9.qasm
# ../limited quantum circuits/qpeinexact_indep_qiskit_6.qasm
# ../limited quantum circuits/twolocalrandom_indep_qiskit_5.qasm
# ../limited quantum circuits/qpeexact_indep_qiskit_3.qasm
# ../limited quantum circuits/su2random_indep_qiskit_2.qasm
# ../limited quantum circuits/realamprandom_indep_qiskit_7.qasm
# ../limited quantum circuits/realamprandom_indep_qiskit_6.qasm
# ../limited quantum circuits/su2random_indep_qiskit_3.qasm
# ../limited quantum circuits/twolocalrandom_indep_qiskit_4.qasm
# ../limited quantum circuits/qpeexact_indep_qiskit_2.qasm
# ../limited quantum circuits/tsp_indep_qiskit_4.qasm
# ../limited quantum circuits/qpeinexact_indep_qiskit_7.qasm
# ../limited quantum circuits/portfoliovqe_indep_qiskit_3.qasm
# ../limited quantum circuits/twolocalrandom_indep_qiskit_8.qasm
# ../limited quantum circuits/qpeinexact_indep_qiskit_4.qasm
# ../limited quantum circuits/realamprandom_indep_qiskit_9.qasm
# ../limited quantum circuits/random_indep_qiskit_2.qasm
# ../limited quantum circuits/qft_indep_qiskit_3.qasm
# ../limited quantum circuits/qpeinexact_indep_qiskit_8.qasm
# ../limited quantum circuits/realamprandom_indep_qiskit_5.qasm
# ../limited quantum circuits/twolocalrandom_indep_qiskit_7.qasm
# ../limited quantum circuits/su2random_indep_qiskit_10.qasm
# ../limited quantum circuits/twolocalrandom_indep_qiskit_6.qasm
# ../limited quantum circuits/realamprandom_indep_qiskit_4.qasm
# ../limited quantum circuits/qpeinexact_indep_qiskit_9.qasm
# ../limited quantum circuits/routing_indep_qiskit_6.qasm
# ../limited quantum circuits/qft_indep_qiskit_2.qasm
# ../limited quantum circuits/random_indep_qiskit_3.qasm
# ../limited quantum circuits/vqe_indep_qiskit_3.qasm
# ../limited quantum circuits/realamprandom_indep_qiskit_8.qasm
# ../limited quantum circuits/qpeinexact_indep_qiskit_5.qasm
# ../limited quantum circuits/vqe_indep_qiskit_8.qasm
# ../limited quantum circuits/realamprandom_indep_qiskit_3.qasm
# ../limited quantum circuits/su2random_indep_qiskit_6.qasm
# ../limited quantum circuits/grover-noancilla_indep_qiskit_3.qasm
# ../limited quantum circuits/qpeinexact_indep_qiskit_2.qasm
# ../limited quantum circuits/vqe_indep_qiskit_4.qasm
# ../limited quantum circuits/qft_indep_qiskit_4.qasm
# ../limited quantum circuits/qpeinexact_indep_qiskit_10.qasm
# ../limited quantum circuits/vqe_indep_qiskit_5.qasm
# ../limited quantum circuits/qpeinexact_indep_qiskit_3.qasm
# ../limited quantum circuits/su2random_indep_qiskit_7.qasm
# ../limited quantum circuits/realamprandom_indep_qiskit_2.qasm
# ../limited quantum circuits/vqe_indep_qiskit_9.qasm

# %%
for key in res_new:
    qc = QuantumCircuit.from_qasm_file(key)
    result_qc_1 = execute(qc, backend=Aer.get_backend('qasm_simulator'), shots=8192).result().get_counts()
    result_qc_2 = execute(qc, backend=Aer.get_backend('qasm_simulator'), shots=8192).result().get_counts()
    print(calculate_tvd(result_qc_1, result_qc_2, 8192))
# Out:
# 0.0196533203125
# 0.0
# 0.0242919921875
# 0.081787109375
# 0.112548828125
# 0.0
# 0.12548828125
# 0.0
# 0.0006103515625
# 0.1190185546875
# 0.019287109375
# 0.0
# 0.023681640625
# 0.006591796875
# 0.0
# 0.01171875
# 0.084716796875
# 0.0177001953125
# 0.0213623046875
# 0.0
# 0.0140380859375
# 0.0555419921875
# 0.0423583984375
# 0.0152587890625
# 0.021484375
# 0.0
# 0.0106201171875
# 0.0272216796875
# 0.0115966796875
# 0.081298828125
# 0.007080078125
# 0.0833740234375
# 0.01123046875
# 0.013916015625
# 0.029541015625
# 0.0255126953125
# 0.048095703125
# 0.160888671875
# 0.03466796875
# 0.0218505859375
# 0.021728515625
# 0.0013427734375
# 0.01025390625
# 0.0098876953125
# 0.007080078125
# 0.0699462890625
# 0.0250244140625
# 0.0167236328125
# 0.0118408203125
# 0.0374755859375
# 0.0
# 0.00830078125
# 0.0
# 0.0224609375
# 0.0235595703125
# 0.001708984375
# 0.00830078125
# 0.060791015625
# 0.002197265625
# 0.01220703125

# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit.quantum_info import partial_trace, Statevector

# define your two states as circuits
psi = QuantumCircuit(5)
psi.ry(np.pi/4.,0)
psi.x(0)
psi.x(1)

psi2 = QuantumCircuit(5)
psi2.ry(np.pi/4.,0)
psi2.x(0)

def first_qubit_state(circuit):
    """Get the statevector for the first qubit, discarding the rest."""
    # get the full statevector of all qubits
    full_statevector = Statevector(circuit)

    # get the density matrix for the first qubit by taking the partial trace
    partial_density_matrix = partial_trace(full_statevector, [1, 2, 3, 4])

    # extract the statevector out of the density matrix
    partial_statevector = np.diagonal(partial_density_matrix)

    return partial_statevector

def compare_first_qubits(circuit1, circuit2):
    """Return True if the statevector of the first qubits is the same."""
    state1 = first_qubit_state(circuit1)
    state2 = first_qubit_state(circuit2)
    return (state1 == state2).all()  # True if all are the same


print('State of first qubit in psi:\n', first_qubit_state(psi))
print('State of first qubit in psi2:\n', first_qubit_state(psi2))
print('Equal?', compare_first_qubits(psi, psi2))
# Out:
# State of first qubit in psi:
#  [0.14644661+0.j 0.85355339+0.j]
# State of first qubit in psi2:
#  [0.14644661+0.j 0.85355339+0.j]
# Equal? True
